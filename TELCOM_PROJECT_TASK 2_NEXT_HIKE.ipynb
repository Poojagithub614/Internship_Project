# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_excel(r'C:\Users\ANKIT\Desktop\Internship_Project\telcom_data.xlsx')

# %%
data.head()
# Out:
#               Bearer Id               Start  Start ms                 End  \
# 0  13114483460844900352 2019-04-04 12:01:18     770.0 2019-04-25 14:35:31
# 1  13114483482878900224 2019-04-09 13:04:04     235.0 2019-04-25 08:15:48
# 2  13114483484080500736 2019-04-09 17:42:11       1.0 2019-04-25 11:58:13
# 3  13114483485442799616 2019-04-10 00:31:25     486.0 2019-04-25 07:36:35
# 4  13114483499480700928 2019-04-12 20:10:23     565.0 2019-04-25 10:40:32
#
#    End ms  Dur. (ms)          IMSI  MSISDN/Number          IMEI  \
# 0   662.0  1823652.0  2.082014e+14   3.366496e+10  3.552121e+13
# 1   606.0  1365104.0  2.082019e+14   3.368185e+10  3.579401e+13
# 2   652.0  1361762.0  2.082003e+14   3.376063e+10  3.528151e+13
# 3   171.0  1321509.0  2.082014e+14   3.375034e+10  3.535661e+13
# 4   954.0  1089009.0  2.082014e+14   3.369980e+10  3.540701e+13
#
#   Last Location Name  ...  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# 0   9164566995485190  ...          15854611.0           2501332.0
# 1            L77566A  ...          20247395.0          19111729.0
# 2            D42335A  ...          19725661.0          14699576.0
# 3            T21824A  ...          21388122.0          15146643.0
# 4            D88865A  ...          15259380.0          18962873.0
#
#    Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# 0           8198936.0           9656251.0        278082303.0
# 1          18338413.0          17227132.0        608750074.0
# 2          17587794.0           6163408.0        229584621.0
# 3          13994646.0           1097942.0        799538153.0
# 4          17124581.0            415218.0        527707248.0
#
#    Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)  Total UL (Bytes)  \
# 0         14344150.0       171744450.0         8814393.0        36749741.0
# 1          1170709.0       526904238.0        15055145.0        53800391.0
# 2           395630.0       410692588.0         4215763.0        27883638.0
# 3         10849722.0       749039933.0        12797283.0        43324218.0
# 4          3529801.0       550709500.0        13910322.0        38542814.0
#
#    Total DL (Bytes)
# 0       308879636.0
# 1       653384965.0
# 2       279807335.0
# 3       846028530.0
# 4       569138589.0
#
# [5 rows x 55 columns]

# %%
data.shape
# Out:
# (150001, 55)

# %%
data.columns
# Out:
# Index(['Bearer Id', 'Start', 'Start ms', 'End', 'End ms', 'Dur. (ms)', 'IMSI',
#        'MSISDN/Number', 'IMEI', 'Last Location Name', 'Avg RTT DL (ms)',
#        'Avg RTT UL (ms)', 'Avg Bearer TP DL (kbps)', 'Avg Bearer TP UL (kbps)',
#        'TCP DL Retrans. Vol (Bytes)', 'TCP UL Retrans. Vol (Bytes)',
#        'DL TP < 50 Kbps (%)', '50 Kbps < DL TP < 250 Kbps (%)',
#        '250 Kbps < DL TP < 1 Mbps (%)', 'DL TP > 1 Mbps (%)',
#        'UL TP < 10 Kbps (%)', '10 Kbps < UL TP < 50 Kbps (%)',
#        '50 Kbps < UL TP < 300 Kbps (%)', 'UL TP > 300 Kbps (%)',
#        'HTTP DL (Bytes)', 'HTTP UL (Bytes)', 'Activity Duration DL (ms)',
#        'Activity Duration UL (ms)', 'Dur. (ms).1', 'Handset Manufacturer',
#        'Handset Type', 'Nb of sec with 125000B < Vol DL',
#        'Nb of sec with 1250B < Vol UL < 6250B',
#        'Nb of sec with 31250B < Vol DL < 125000B',
#        'Nb of sec with 37500B < Vol UL',
#        'Nb of sec with 6250B < Vol DL < 31250B',
#        'Nb of sec with 6250B < Vol UL < 37500B',
#        'Nb of sec with Vol DL < 6250B', 'Nb of sec with Vol UL < 1250B',
#        'Social Media DL (Bytes)', 'Social Media UL (Bytes)',
#        'Google DL (Bytes)', 'Google UL (Bytes)', 'Email DL (Bytes)',
#        'Email UL (Bytes)', 'Youtube DL (Bytes)', 'Youtube UL (Bytes)',
#        'Netflix DL (Bytes)', 'Netflix UL (Bytes)', 'Gaming DL (Bytes)',
#        'Gaming UL (Bytes)', 'Other DL (Bytes)', 'Other UL (Bytes)',
#        'Total UL (Bytes)', 'Total DL (Bytes)'],
#       dtype='object')

# %%
len(data['End ms'])
# Out:
# 150001

# %%
df={"Bearer Id":data["Bearer Id"],"Start ms":data["Start ms"],"MSISDN/Number":data["MSISDN/Number"],"End ms":data["End ms"],"Dur. (ms)":data["Dur. (ms)"],"Avg RTT DL (ms)":data["Avg RTT DL (ms)"],
   "Avg RTT UL (ms)":data["Avg RTT UL (ms)"],"Activity Duration DL (ms)":data["Activity Duration DL (ms)"],"Activity Duration UL (ms)":data["Activity Duration UL (ms)"],}

# %%
d=pd.DataFrame(df)

# %%
d
# Out:
#                    Bearer Id  Start ms  MSISDN/Number  End ms  Dur. (ms)  \
# 0       13114483460844900352     770.0   3.366496e+10   662.0  1823652.0
# 1       13114483482878900224     235.0   3.368185e+10   606.0  1365104.0
# 2       13114483484080500736       1.0   3.376063e+10   652.0  1361762.0
# 3       13114483485442799616     486.0   3.375034e+10   171.0  1321509.0
# 4       13114483499480700928     565.0   3.369980e+10   954.0  1089009.0
# ...                      ...       ...            ...     ...        ...
# 149996   7277825670196679680     451.0   3.365069e+10   214.0    81230.0
# 149997   7349883264234609664     483.0   3.366345e+10   187.0    97970.0
# 149998  13114483573367300096     283.0   3.362189e+10   810.0    98249.0
# 149999  13114483573367300096     696.0   3.361962e+10   327.0    97910.0
# 150000                             NaN            NaN     NaN        NaN
#
#         Avg RTT DL (ms)  Avg RTT UL (ms)  Activity Duration DL (ms)  \
# 0                  42.0              5.0                    37624.0
# 1                  65.0              5.0                      168.0
# 2                   NaN              NaN                        0.0
# 3                   NaN              NaN                     3330.0
# 4                   NaN              NaN                        0.0
# ...                 ...              ...                        ...
# 149996             32.0              0.0                    42376.0
# 149997             27.0              2.0                    17264.0
# 149998             43.0              6.0                    25003.0
# 149999             37.0              5.0                    13405.0
# 150000              NaN              NaN                        NaN
#
#         Activity Duration UL (ms)
# 0                         38787.0
# 1                          3560.0
# 2                             0.0
# 3                         37882.0
# 4                             0.0
# ...                           ...
# 149996                    41915.0
# 149997                    16759.0
# 149998                    28640.0
# 149999                    34088.0
# 150000                        NaN
#
# [150001 rows x 9 columns]

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150001 entries, 0 to 150000
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Bearer Id                  150001 non-null  object
#  1   Start ms                   150000 non-null  float64
#  2   MSISDN/Number              148935 non-null  float64
#  3   End ms                     150000 non-null  float64
#  4   Dur. (ms)                  150000 non-null  float64
#  5   Avg RTT DL (ms)            122172 non-null  float64
#  6   Avg RTT UL (ms)            122189 non-null  float64
#  7   Activity Duration DL (ms)  150000 non-null  float64
#  8   Activity Duration UL (ms)  150000 non-null  float64
# dtypes: float64(8), object(1)
# memory usage: 10.3+ MB

# %% [markdown]
# # Session Frequency

# %%
session_frequency = data.groupby(by=['MSISDN/Number'])['Dur. (ms)'].transform('count')

# %%
len(session_frequency)
# Out:
# 150001

# %%
session_frequency.plot(kind='hist', bins=10)

plt.xlabel('Session Frequency')
plt.ylabel('Count')
plt.title('Distribution of Session Frequency')
plt.show()

# %%
# Create a distribution plot using distplot
sns.distplot(session_frequency, kde=True)

plt.xlabel('Session Frequency')
plt.ylabel('Density')
plt.title('Distribution of Session Frequency')

plt.show()

# %% [markdown]
# # Session frquency based on handset type and Manufacturer

# %%
# Group the data by 'Handset Type' and 'MSISDN/Number' and count the number of unique sessions
session_f = data.groupby(['Handset Type', 'MSISDN/Number'])['Dur. (ms)'].count().reset_index()

# Rename the column containing the session frequency count
session_f.rename(columns={'Dur. (ms)': 'Session F'}, inplace=True)

# Group the data by 'Handset Type' and calculate the total session frequency
type_frequency = session_f.groupby('Handset Type')['Session F'].sum().reset_index()

# Sort the data by session frequency in descending order
type_frequency = type_frequency.sort_values('Session F', ascending=False).head(10)

# Plot the session frequency by handset type
plt.figure(figsize=(10, 6))
sns.barplot(data=type_frequency, x='Handset Type', y='Session F')
plt.xlabel('Handset Type')
plt.ylabel('Session Frequency')
plt.title('Top 10 Handset Types by Session Frequency')
plt.xticks(rotation=90)
plt.show()

# %%
# Group the data by 'Handset Manufacturer' and 'MSISDN/Number' and count the number of unique sessions
session_frequency1 = data.groupby(['Handset Manufacturer', 'MSISDN/Number'])['Dur. (ms)'].count().reset_index()

# Rename the column containing the session frequency count
session_frequency1.rename(columns={'Dur. (ms)': 'Session Frequency1'}, inplace=True)

# Group the data by 'Handset Manufacturer' and calculate the total session frequency
manufacturer_frequency = session_frequency1.groupby('Handset Manufacturer')['Session Frequency1'].sum().reset_index()

# Sort the data by session frequency in descending order
manufacturer_frequency = manufacturer_frequency.sort_values('Session Frequency1', ascending=False).head(10)

# Plot the session frequency by handset manufacturer
plt.figure(figsize=(10, 6))
sns.barplot(data=manufacturer_frequency, x='Handset Manufacturer', y='Session Frequency1')
plt.xlabel('Handset Manufacturer')
plt.ylabel('Session Frequency1')
plt.title('Top 10 Handset Manufacturers by Session Frequency')
plt.xticks(rotation=90)
plt.show()

# %%
# Group the data by 'Handset Type' and 'MSISDN/Number' and count the number of unique sessions
session_frequency_type = data.groupby(['Handset Type', 'MSISDN/Number'])['Dur. (ms)'].count().reset_index()

# Rename the column containing the session frequency count
session_frequency_type.rename(columns={'Dur. (ms)': 'Session F'}, inplace=True)

# Group the data by 'Handset Type' and calculate the total session frequency
type_frequency = session_frequency_type.groupby('Handset Type')['Session F'].sum().reset_index()

# Sort the data by session frequency in descending order
type_frequency = type_frequency.sort_values('Session F', ascending=False).head(10)

# Group the data by 'Handset Manufacturer' and 'MSISDN/Number' and count the number of unique sessions
session_frequency_manufacturer = data.groupby(['Handset Manufacturer', 'MSISDN/Number'])['Dur. (ms)'].count().reset_index()

# Rename the column containing the session frequency count
session_frequency_manufacturer.rename(columns={'Dur. (ms)': 'Session F'}, inplace=True)

# Group the data by 'Handset Manufacturer' and calculate the total session frequency
manufacturer_frequency = session_frequency_manufacturer.groupby('Handset Manufacturer')['Session F'].sum().reset_index()

# Sort the data by session frequency in descending order
manufacturer_frequency = manufacturer_frequency.sort_values('Session F', ascending=False).head(10)

# Plotting
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# Plot session frequency by handset type
sns.barplot(data=type_frequency, x='Handset Type', y='Session F', ax=axes[0])
axes[0].set_xlabel('Handset Type')
axes[0].set_ylabel('Session Frequency')
axes[0].set_title('Top 10 Handset Types by Session Frequency')
axes[0].tick_params(axis='x', rotation=90)

# Plot session frequency by handset manufacturer
sns.barplot(data=manufacturer_frequency, x='Handset Manufacturer', y='Session F', ax=axes[1])
axes[1].set_xlabel('Handset Manufacturer')
axes[1].set_ylabel('Session Frequency')
axes[1].set_title('Top 10 Handset Manufacturers by Session Frequency')
axes[1].tick_params(axis='x', rotation=90)

plt.tight_layout()
plt.show()

# %%
# Plotting a pie chart for session frequency by handset type
plt.figure(figsize=(8, 6))
plt.pie(type_frequency['Session F'], labels=type_frequency['Handset Type'], autopct='%1.1f%%')
plt.title('Session Frequency by  top 10 Handset Type')
plt.show()

# %% [markdown]
# # Session Duration

# %%
# Calculate session duration by subtracting "End ms" from "Start ms"
Session_Duration = data['Dur. (ms)']



# Print the session duration for each "Bearer Id"
print(Session_Duration)
# Out:
# 0         1823652.0
# 1         1365104.0
# 2         1361762.0
# 3         1321509.0
# 4         1089009.0
#             ...
# 149996      81230.0
# 149997      97970.0
# 149998      98249.0
# 149999      97910.0
# 150000          NaN
# Name: Dur. (ms), Length: 150001, dtype: float64

# %%
plt.figure(figsize=(10, 6))
plt.hist(Session_Duration, bins=10, edgecolor='black')
plt.title('Session Duration Distribution')
plt.xlabel('Session Duration (ms)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # As the count increases the duration decreases

# %%
d.describe()
# Out:
#             Start ms  MSISDN/Number         End ms     Dur. (ms)  \
# count  150000.000000   1.489350e+05  150000.000000  1.500000e+05
# mean      499.188200   4.188282e+10     498.800880  1.046086e+05
# std       288.611834   2.447443e+12     288.097653  8.103762e+04
# min         0.000000   3.360100e+10       0.000000  7.142000e+03
# 25%       250.000000   3.365130e+10     251.000000  5.744050e+04
# 50%       499.000000   3.366371e+10     500.000000  8.639900e+04
# 75%       749.000000   3.368349e+10     750.000000  1.324302e+05
# max       999.000000   8.823971e+14     999.000000  1.859336e+06
#
#        Avg RTT DL (ms)  Avg RTT UL (ms)  Activity Duration DL (ms)  \
# count    122172.000000    122189.000000               1.500000e+05
# mean        109.795706        17.662883               1.829177e+06
# std         619.782739        84.793524               5.696395e+06
# min           0.000000         0.000000               0.000000e+00
# 25%          32.000000         2.000000               1.487775e+04
# 50%          45.000000         5.000000               3.930450e+04
# 75%          70.000000        15.000000               6.796095e+05
# max       96923.000000      7120.000000               1.365365e+08
#
#        Activity Duration UL (ms)
# count               1.500000e+05
# mean                1.408880e+06
# std                 4.643231e+06
# min                 0.000000e+00
# 25%                 2.153975e+04
# 50%                 4.679350e+04
# 75%                 5.990952e+05
# max                 1.449113e+08

# %% [markdown]
# # Total traffic of pages visited on a website in a single go.

# %%
total_traffic = data['Total DL (Bytes)'] + data['Total UL (Bytes)']

# %%
plt.figure(figsize=(10, 6))
plt.scatter(Session_Duration, total_traffic)
plt.title('Total Traffic vs. Session Duration')
plt.xlabel('Session Duration')
plt.ylabel('Total Traffic')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(Session_Duration, total_traffic)
plt.title('Total Traffic vs. Session Duration')
plt.xlabel('Session Duration')
plt.ylabel('Total Traffic')
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(total_traffic, bins=10, edgecolor='black')
plt.title('Total Traffic Distribution')
plt.xlabel('Total Traffic')
plt.ylabel('Frequency')
plt.show()

# %%
total_traffic
# Out:
# 0         345629377.0
# 1         707185356.0
# 2         307690973.0
# 3         889352748.0
# 4         607681403.0
#              ...
# 149996    631804110.0
# 149997    705783925.0
# 149998    627698629.0
# 149999    401522016.0
# 150000            NaN
# Length: 150001, dtype: float64

# %%
d.columns
# Out:
# Index(['Bearer Id', 'Start ms', 'MSISDN/Number', 'End ms', 'Dur. (ms)',
#        'Avg RTT DL (ms)', 'Avg RTT UL (ms)', 'Activity Duration DL (ms)',
#        'Activity Duration UL (ms)'],
#       dtype='object')

# %%
b={'MSISDN/Number':data['MSISDN/Number'],"session_frequency":session_frequency,"session_duration":Session_Duration,'total_traffic':total_traffic}

# %%
c=pd.DataFrame(b)

# %%
c
# Out:
#         MSISDN/Number  session_frequency  session_duration  total_traffic
# 0        3.366496e+10                2.0         1823652.0    345629377.0
# 1        3.368185e+10                2.0         1365104.0    707185356.0
# 2        3.376063e+10                1.0         1361762.0    307690973.0
# 3        3.375034e+10                1.0         1321509.0    889352748.0
# 4        3.369980e+10                1.0         1089009.0    607681403.0
# ...               ...                ...               ...            ...
# 149996   3.365069e+10                1.0           81230.0    631804110.0
# 149997   3.366345e+10                2.0           97970.0    705783925.0
# 149998   3.362189e+10                1.0           98249.0    627698629.0
# 149999   3.361962e+10                1.0           97910.0    401522016.0
# 150000            NaN                NaN               NaN            NaN
#
# [150001 rows x 4 columns]

# %%
for i in c.columns:
   
    # check if the datatype is object or not
    if c[i].dtypes == "object":
        
        mode_value = c[i].mode()[0]
        c[i].fillna(mode_value, inplace = True)
    elif c[i].dtypes != "object":
        mean_value = c[i].mean()
        c[i].fillna(mean_value, inplace = True)

# %%
dframe=pd.concat([c,data],axis=0)

# %% [markdown]
# #Task 2.1 Aggregate the metrics per customer ID & Report the top 10 customers per engagement metric

# %%
aggregated_data = dframe.groupby('MSISDN/Number').agg({
    'session_frequency': 'mean',
    'session_duration': 'sum',
    'total_traffic': 'sum',
    'Social Media DL (Bytes)': 'sum',
    'Social Media UL (Bytes)': 'sum',
    'Google DL (Bytes)': 'sum',
    'Google UL (Bytes)': 'sum',
    'Email DL (Bytes)': 'sum',
    'Email UL (Bytes)': 'sum',
    'Youtube DL (Bytes)': 'sum',
    'Youtube UL (Bytes)': 'sum',
    'Netflix DL (Bytes)': 'sum',
    'Netflix UL (Bytes)': 'sum',
    'Gaming DL (Bytes)': 'sum',
    'Gaming UL (Bytes)': 'sum',
    'Other DL (Bytes)': 'sum',
    'Other UL (Bytes)': 'sum',
})

top_10_frequency = aggregated_data.nlargest(10, 'session_frequency')
top_10_duration = aggregated_data.nlargest(10, 'session_duration')
top_10_traffic = aggregated_data.nlargest(10, 'total_traffic')
top_10_social_media = aggregated_data.nlargest(10, 'Social Media DL (Bytes)')
top_10_google = aggregated_data.nlargest(10, 'Google DL (Bytes)')
top_10_email = aggregated_data.nlargest(10, 'Email DL (Bytes)')
top_10_youtube = aggregated_data.nlargest(10, 'Youtube DL (Bytes)')
top_10_netflix = aggregated_data.nlargest(10, 'Netflix DL (Bytes)')
top_10_gaming = aggregated_data.nlargest(10, 'Gaming DL (Bytes)')
top_10_other = aggregated_data.nlargest(10, 'Other DL (Bytes)')

#print the result
print("Top 10 Customers by Session Frequency:")
print(top_10_frequency)
print("\nTop 10 Customers by Session Duration:")
print(top_10_duration)
print("\nTop 10 Customers by Total_Traffic:")
print(top_10_traffic)
print("\nTop 10 Customers by Social Media Usage:")
print(top_10_social_media)
print("\nTop 10 Customers by Google Usage:")
print(top_10_google)
print("\nTop 10 Customers by Email Usage:")
print(top_10_email)
print("\nTop 10 Customers by Youtube Usage:")
print(top_10_youtube)
print("\nTop 10 Customers by Netflix Usage:")
print(top_10_netflix)
print("\nTop 10 Customers by Gaming Usage:")
print(top_10_gaming)
print("\nTop 10 Customers by Other Data Usage:")
print(top_10_other)
# Out:
# Top 10 Customers by Session Frequency:
#                session_frequency  session_duration  total_traffic  \
# MSISDN/Number
# 3.362632e+10                18.0         8791927.0   7.971167e+09
# 3.361489e+10                17.0         9966898.0   8.846226e+09
# 3.362578e+10                17.0        18553754.0   8.499621e+09
# 3.365973e+10                16.0         4035428.0   7.705863e+09
# 3.367588e+10                15.0         4865947.0   7.891111e+09
# 3.376054e+10                15.0         9279434.0   8.514774e+09
# 3.366716e+10                13.0         8744914.0   5.618394e+09
# 3.360313e+10                12.0         6287761.0   4.976195e+09
# 3.360452e+10                12.0         5207990.0   5.487855e+09
# 3.362708e+10                12.0         4703516.0   5.754731e+09
#
#                Social Media DL (Bytes)  Social Media UL (Bytes)  \
# MSISDN/Number
# 3.362632e+10                42743837.0                 630942.0
# 3.361489e+10                27749744.0                 544800.0
# 3.362578e+10                26564121.0                 571379.0
# 3.365973e+10                34900444.0                 511914.0
# 3.367588e+10                18655364.0                 567557.0
# 3.376054e+10                39297646.0                 485543.0
# 3.366716e+10                23753753.0                 494097.0
# 3.360313e+10                22776679.0                 301146.0
# 3.360452e+10                18083725.0                 392798.0
# 3.362708e+10                17438671.0                 370240.0
#
#                Google DL (Bytes)  Google UL (Bytes)  Email DL (Bytes)  \
# MSISDN/Number
# 3.362632e+10         116106455.0         36085397.0        33404785.0
# 3.361489e+10          93941708.0         34032079.0        33607211.0
# 3.362578e+10         107904739.0         34403176.0        31895412.0
# 3.365973e+10          90958549.0         25557796.0        29907647.0
# 3.367588e+10          83002994.0         26857508.0        24284723.0
# 3.376054e+10          88626532.0         34596567.0        26437895.0
# 3.366716e+10          71707826.0         33324870.0        23276752.0
# 3.360313e+10          73942055.0         12986961.0        20343728.0
# 3.360452e+10          57706148.0         26108889.0        19397083.0
# 3.362708e+10          62722401.0         24403520.0        17353955.0
#
#                Email UL (Bytes)  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# MSISDN/Number
# 3.362632e+10          9013997.0         164048706.0         210434341.0
# 3.361489e+10          7181423.0         199823443.0         194546775.0
# 3.362578e+10          8738554.0         237883033.0         215075736.0
# 3.365973e+10          6092145.0         119658146.0         138332942.0
# 3.367588e+10          7229698.0         158665235.0         158745337.0
# 3.376054e+10          7255872.0         194068298.0         202220900.0
# 3.366716e+10          7059044.0         141972692.0         173258618.0
# 3.360313e+10          5855167.0         158976704.0         125113435.0
# 3.360452e+10          4457346.0          83169358.0          96517390.0
# 3.362708e+10          6213264.0         187323322.0         121467452.0
#
#                Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# MSISDN/Number
# 3.362632e+10          199479238.0         129246502.0       6.745734e+09
# 3.361489e+10          179585986.0         181815060.0       7.622035e+09
# 3.362578e+10          193912238.0         163068369.0       7.171884e+09
# 3.365973e+10          196277206.0         203241873.0       6.609900e+09
# 3.367588e+10          161626462.0         147466697.0       6.863307e+09
# 3.376054e+10          146500839.0         188142430.0       7.316364e+09
# 3.366716e+10          167932406.0         146007082.0       4.623424e+09
# 3.360313e+10          156086546.0         104401875.0       4.108482e+09
# 3.360452e+10          151330389.0         114043873.0       4.766393e+09
# 3.362708e+10          144623204.0         122417693.0       4.880017e+09
#
#                Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)
# MSISDN/Number
# 3.362632e+10         141838597.0      8.025477e+09       142400945.0
# 3.361489e+10         127396833.0      7.495298e+09       143966031.0
# 3.362578e+10         154789688.0      6.201653e+09       152930478.0
# 3.365973e+10         115658741.0      6.182551e+09       134864910.0
# 3.367588e+10         107260559.0      6.665074e+09       133441436.0
# 3.376054e+10         144681056.0      4.590038e+09       126096213.0
# 3.366716e+10         102197663.0      4.837534e+09       103984990.0
# 3.360313e+10          82962892.0      6.222705e+09       103966155.0
# 3.360452e+10          80270693.0      4.059958e+09        69984867.0
# 3.362708e+10          92335582.0      5.039747e+09        78044196.0
#
# Top 10 Customers by Session Duration:
#                session_frequency  session_duration  total_traffic  \
# MSISDN/Number
# 4.188282e+10            1.859905      7.255100e+07   5.317447e+11
# 3.362578e+10           17.000000      1.855375e+07   8.499621e+09
# 3.361489e+10           17.000000      9.966898e+06   8.846226e+09
# 3.376054e+10           15.000000      9.279434e+06   8.514774e+09
# 3.362632e+10           18.000000      8.791927e+06   7.971167e+09
# 3.366716e+10           13.000000      8.744914e+06   5.618394e+09
# 3.366284e+10            9.000000      6.614270e+06   4.000098e+09
# 3.366469e+10            9.000000      6.288730e+06   5.682007e+09
# 3.360313e+10           12.000000      6.287761e+06   4.976195e+09
# 3.366746e+10            6.000000      5.649882e+06   2.600522e+09
#
#                Social Media DL (Bytes)  Social Media UL (Bytes)  \
# MSISDN/Number
# 4.188282e+10                       0.0                      0.0
# 3.362578e+10                26564121.0                 571379.0
# 3.361489e+10                27749744.0                 544800.0
# 3.376054e+10                39297646.0                 485543.0
# 3.362632e+10                42743837.0                 630942.0
# 3.366716e+10                23753753.0                 494097.0
# 3.366284e+10                17103694.0                 360240.0
# 3.366469e+10                16834010.0                 351031.0
# 3.360313e+10                22776679.0                 301146.0
# 3.366746e+10                 7606997.0                 177076.0
#
#                Google DL (Bytes)  Google UL (Bytes)  Email DL (Bytes)  \
# MSISDN/Number
# 4.188282e+10                 0.0                0.0               0.0
# 3.362578e+10         107904739.0         34403176.0        31895412.0
# 3.361489e+10          93941708.0         34032079.0        33607211.0
# 3.376054e+10          88626532.0         34596567.0        26437895.0
# 3.362632e+10         116106455.0         36085397.0        33404785.0
# 3.366716e+10          71707826.0         33324870.0        23276752.0
# 3.366284e+10          48489232.0         15474271.0        13707750.0
# 3.366469e+10          54588663.0         18994447.0        12978367.0
# 3.360313e+10          73942055.0         12986961.0        20343728.0
# 3.366746e+10          30111394.0          9322276.0        16987953.0
#
#                Email UL (Bytes)  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# MSISDN/Number
# 4.188282e+10                0.0                 0.0                 0.0
# 3.362578e+10          8738554.0         237883033.0         215075736.0
# 3.361489e+10          7181423.0         199823443.0         194546775.0
# 3.376054e+10          7255872.0         194068298.0         202220900.0
# 3.362632e+10          9013997.0         164048706.0         210434341.0
# 3.366716e+10          7059044.0         141972692.0         173258618.0
# 3.366284e+10          4183849.0         120342889.0         142655957.0
# 3.366469e+10          4601251.0         126220891.0          79146878.0
# 3.360313e+10          5855167.0         158976704.0         125113435.0
# 3.366746e+10          3050111.0          69628569.0          76010354.0
#
#                Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# MSISDN/Number
# 4.188282e+10                  0.0                 0.0       0.000000e+00
# 3.362578e+10          193912238.0         163068369.0       7.171884e+09
# 3.361489e+10          179585986.0         181815060.0       7.622035e+09
# 3.376054e+10          146500839.0         188142430.0       7.316364e+09
# 3.362632e+10          199479238.0         129246502.0       6.745734e+09
# 3.366716e+10          167932406.0         146007082.0       4.623424e+09
# 3.366284e+10          110184890.0          74082924.0       3.283845e+09
# 3.366469e+10          129706681.0         131857877.0       4.939498e+09
# 3.360313e+10          156086546.0         104401875.0       4.108482e+09
# 3.366746e+10           94654071.0          79389387.0       2.115310e+09
#
#                Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)
# MSISDN/Number
# 4.188282e+10                 0.0      0.000000e+00               0.0
# 3.362578e+10         154789688.0      6.201653e+09       152930478.0
# 3.361489e+10         127396833.0      7.495298e+09       143966031.0
# 3.376054e+10         144681056.0      4.590038e+09       126096213.0
# 3.362632e+10         141838597.0      8.025477e+09       142400945.0
# 3.366716e+10         102197663.0      4.837534e+09       103984990.0
# 3.366284e+10          67257928.0      3.893377e+09       102409203.0
# 3.366469e+10          69322418.0      4.862951e+09        97906902.0
# 3.360313e+10          82962892.0      6.222705e+09       103966155.0
# 3.366746e+10          42848778.0      2.776996e+09        55424665.0
#
# Top 10 Customers by Total_Traffic:
#                session_frequency  session_duration  total_traffic  \
# MSISDN/Number
# 4.188282e+10            1.859905      7.255100e+07   5.317447e+11
# 3.361489e+10           17.000000      9.966898e+06   8.846226e+09
# 3.376054e+10           15.000000      9.279434e+06   8.514774e+09
# 3.362578e+10           17.000000      1.855375e+07   8.499621e+09
# 3.362632e+10           18.000000      8.791927e+06   7.971167e+09
# 3.367588e+10           15.000000      4.865947e+06   7.891111e+09
# 3.365973e+10           16.000000      4.035428e+06   7.705863e+09
# 3.366646e+10           11.000000      4.536757e+06   7.308501e+09
# 3.376041e+10           12.000000      5.321667e+06   7.132371e+09
# 3.366471e+10           11.000000      2.927785e+06   6.872018e+09
#
#                Social Media DL (Bytes)  Social Media UL (Bytes)  \
# MSISDN/Number
# 4.188282e+10                       0.0                      0.0
# 3.361489e+10                27749744.0                 544800.0
# 3.376054e+10                39297646.0                 485543.0
# 3.362578e+10                26564121.0                 571379.0
# 3.362632e+10                42743837.0                 630942.0
# 3.367588e+10                18655364.0                 567557.0
# 3.365973e+10                34900444.0                 511914.0
# 3.366646e+10                18234924.0                 395062.0
# 3.376041e+10                20515774.0                 261431.0
# 3.366471e+10                19035729.0                 354870.0
#
#                Google DL (Bytes)  Google UL (Bytes)  Email DL (Bytes)  \
# MSISDN/Number
# 4.188282e+10                 0.0                0.0               0.0
# 3.361489e+10          93941708.0         34032079.0        33607211.0
# 3.376054e+10          88626532.0         34596567.0        26437895.0
# 3.362578e+10         107904739.0         34403176.0        31895412.0
# 3.362632e+10         116106455.0         36085397.0        33404785.0
# 3.367588e+10          83002994.0         26857508.0        24284723.0
# 3.365973e+10          90958549.0         25557796.0        29907647.0
# 3.366646e+10          62599213.0         26721524.0        19667181.0
# 3.376041e+10          56331853.0         26406867.0        21791296.0
# 3.366471e+10          64946017.0         25443355.0        15213560.0
#
#                Email UL (Bytes)  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# MSISDN/Number
# 4.188282e+10                0.0                 0.0                 0.0
# 3.361489e+10          7181423.0         199823443.0         194546775.0
# 3.376054e+10          7255872.0         194068298.0         202220900.0
# 3.362578e+10          8738554.0         237883033.0         215075736.0
# 3.362632e+10          9013997.0         164048706.0         210434341.0
# 3.367588e+10          7229698.0         158665235.0         158745337.0
# 3.365973e+10          6092145.0         119658146.0         138332942.0
# 3.366646e+10          5889958.0         140663858.0          86672154.0
# 3.376041e+10          3785669.0         174245981.0         128923126.0
# 3.366471e+10          6212447.0         153074482.0         123759531.0
#
#                Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# MSISDN/Number
# 4.188282e+10                  0.0                 0.0       0.000000e+00
# 3.361489e+10          179585986.0         181815060.0       7.622035e+09
# 3.376054e+10          146500839.0         188142430.0       7.316364e+09
# 3.362578e+10          193912238.0         163068369.0       7.171884e+09
# 3.362632e+10          199479238.0         129246502.0       6.745734e+09
# 3.367588e+10          161626462.0         147466697.0       6.863307e+09
# 3.365973e+10          196277206.0         203241873.0       6.609900e+09
# 3.366646e+10          115946985.0          98469941.0       6.546328e+09
# 3.376041e+10          167023809.0         151323737.0       6.170943e+09
# 3.366471e+10          134941569.0         116857240.0       6.013562e+09
#
#                Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)
# MSISDN/Number
# 4.188282e+10                 0.0      0.000000e+00               0.0
# 3.361489e+10         127396833.0      7.495298e+09       143966031.0
# 3.376054e+10         144681056.0      4.590038e+09       126096213.0
# 3.362578e+10         154789688.0      6.201653e+09       152930478.0
# 3.362632e+10         141838597.0      8.025477e+09       142400945.0
# 3.367588e+10         107260559.0      6.665074e+09       133441436.0
# 3.365973e+10         115658741.0      6.182551e+09       134864910.0
# 3.366646e+10          99975537.0      4.262205e+09        86936800.0
# 3.376041e+10          97676681.0      3.988504e+09       113141379.0
# 3.366471e+10          90293610.0      3.868637e+09       108323400.0
#
# Top 10 Customers by Social Media Usage:
#                session_frequency  session_duration  total_traffic  \
# MSISDN/Number
# 3.362632e+10                18.0         8791927.0   7.971167e+09
# 3.376054e+10                15.0         9279434.0   8.514774e+09
# 3.365973e+10                16.0         4035428.0   7.705863e+09
# 3.361489e+10                17.0         9966898.0   8.846226e+09
# 3.362578e+10                17.0        18553754.0   8.499621e+09
# 3.366716e+10                13.0         8744914.0   5.618394e+09
# 3.378632e+10                12.0         4059652.0   5.622232e+09
# 3.366907e+10                11.0          610801.0   3.906542e+09
# 3.360313e+10                12.0         6287761.0   4.976195e+09
# 3.365849e+10                 9.0         3061779.0   2.690139e+09
#
#                Social Media DL (Bytes)  Social Media UL (Bytes)  \
# MSISDN/Number
# 3.362632e+10                42743837.0                 630942.0
# 3.376054e+10                39297646.0                 485543.0
# 3.365973e+10                34900444.0                 511914.0
# 3.361489e+10                27749744.0                 544800.0
# 3.362578e+10                26564121.0                 571379.0
# 3.366716e+10                23753753.0                 494097.0
# 3.378632e+10                23568655.0                 406264.0
# 3.366907e+10                23477047.0                 323787.0
# 3.360313e+10                22776679.0                 301146.0
# 3.365849e+10                22695673.0                 304393.0
#
#                Google DL (Bytes)  Google UL (Bytes)  Email DL (Bytes)  \
# MSISDN/Number
# 3.362632e+10         116106455.0         36085397.0        33404785.0
# 3.376054e+10          88626532.0         34596567.0        26437895.0
# 3.365973e+10          90958549.0         25557796.0        29907647.0
# 3.361489e+10          93941708.0         34032079.0        33607211.0
# 3.362578e+10         107904739.0         34403176.0        31895412.0
# 3.366716e+10          71707826.0         33324870.0        23276752.0
# 3.378632e+10          78819810.0         31434674.0        30876908.0
# 3.366907e+10          54915216.0         22909468.0        17813584.0
# 3.360313e+10          73942055.0         12986961.0        20343728.0
# 3.365849e+10          55457602.0         20976541.0        15004556.0
#
#                Email UL (Bytes)  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# MSISDN/Number
# 3.362632e+10          9013997.0         164048706.0         210434341.0
# 3.376054e+10          7255872.0         194068298.0         202220900.0
# 3.365973e+10          6092145.0         119658146.0         138332942.0
# 3.361489e+10          7181423.0         199823443.0         194546775.0
# 3.362578e+10          8738554.0         237883033.0         215075736.0
# 3.366716e+10          7059044.0         141972692.0         173258618.0
# 3.378632e+10          5433215.0         118129859.0          96634053.0
# 3.366907e+10          5109829.0         136295265.0         100107539.0
# 3.360313e+10          5855167.0         158976704.0         125113435.0
# 3.365849e+10          4673135.0          64799443.0         118464776.0
#
#                Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# MSISDN/Number
# 3.362632e+10          199479238.0         129246502.0       6.745734e+09
# 3.376054e+10          146500839.0         188142430.0       7.316364e+09
# 3.365973e+10          196277206.0         203241873.0       6.609900e+09
# 3.361489e+10          179585986.0         181815060.0       7.622035e+09
# 3.362578e+10          193912238.0         163068369.0       7.171884e+09
# 3.366716e+10          167932406.0         146007082.0       4.623424e+09
# 3.378632e+10          163602702.0         142337088.0       4.740903e+09
# 3.366907e+10           78923699.0         133085331.0       3.166462e+09
# 3.360313e+10          156086546.0         104401875.0       4.108482e+09
# 3.365849e+10           78217369.0         108576562.0       2.071045e+09
#
#                Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)
# MSISDN/Number
# 3.362632e+10         141838597.0      8.025477e+09       142400945.0
# 3.376054e+10         144681056.0      4.590038e+09       126096213.0
# 3.365973e+10         115658741.0      6.182551e+09       134864910.0
# 3.361489e+10         127396833.0      7.495298e+09       143966031.0
# 3.362578e+10         154789688.0      6.201653e+09       152930478.0
# 3.366716e+10         102197663.0      4.837534e+09       103984990.0
# 3.378632e+10         110192303.0      4.172594e+09        79892668.0
# 3.366907e+10         102690051.0      4.540939e+09        64429870.0
# 3.360313e+10          82962892.0      6.222705e+09       103966155.0
# 3.365849e+10          54024030.0      4.239611e+09        75899582.0
#
# Top 10 Customers by Google Usage:
#                session_frequency  session_duration  total_traffic  \
# MSISDN/Number
# 3.362632e+10                18.0         8791927.0   7.971167e+09
# 3.362578e+10                17.0        18553754.0   8.499621e+09
# 3.361489e+10                17.0         9966898.0   8.846226e+09
# 3.365973e+10                16.0         4035428.0   7.705863e+09
# 3.376054e+10                15.0         9279434.0   8.514774e+09
# 3.367588e+10                15.0         4865947.0   7.891111e+09
# 3.378632e+10                12.0         4059652.0   5.622232e+09
# 3.360313e+10                12.0         6287761.0   4.976195e+09
# 3.376127e+10                10.0         3481629.0   5.051114e+09
# 3.366716e+10                13.0         8744914.0   5.618394e+09
#
#                Social Media DL (Bytes)  Social Media UL (Bytes)  \
# MSISDN/Number
# 3.362632e+10                42743837.0                 630942.0
# 3.362578e+10                26564121.0                 571379.0
# 3.361489e+10                27749744.0                 544800.0
# 3.365973e+10                34900444.0                 511914.0
# 3.376054e+10                39297646.0                 485543.0
# 3.367588e+10                18655364.0                 567557.0
# 3.378632e+10                23568655.0                 406264.0
# 3.360313e+10                22776679.0                 301146.0
# 3.376127e+10                14201427.0                 294653.0
# 3.366716e+10                23753753.0                 494097.0
#
#                Google DL (Bytes)  Google UL (Bytes)  Email DL (Bytes)  \
# MSISDN/Number
# 3.362632e+10         116106455.0         36085397.0        33404785.0
# 3.362578e+10         107904739.0         34403176.0        31895412.0
# 3.361489e+10          93941708.0         34032079.0        33607211.0
# 3.365973e+10          90958549.0         25557796.0        29907647.0
# 3.376054e+10          88626532.0         34596567.0        26437895.0
# 3.367588e+10          83002994.0         26857508.0        24284723.0
# 3.378632e+10          78819810.0         31434674.0        30876908.0
# 3.360313e+10          73942055.0         12986961.0        20343728.0
# 3.376127e+10          72949803.0         24140185.0        15768841.0
# 3.366716e+10          71707826.0         33324870.0        23276752.0
#
#                Email UL (Bytes)  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# MSISDN/Number
# 3.362632e+10          9013997.0         164048706.0         210434341.0
# 3.362578e+10          8738554.0         237883033.0         215075736.0
# 3.361489e+10          7181423.0         199823443.0         194546775.0
# 3.365973e+10          6092145.0         119658146.0         138332942.0
# 3.376054e+10          7255872.0         194068298.0         202220900.0
# 3.367588e+10          7229698.0         158665235.0         158745337.0
# 3.378632e+10          5433215.0         118129859.0          96634053.0
# 3.360313e+10          5855167.0         158976704.0         125113435.0
# 3.376127e+10          4984880.0         119056471.0         153733121.0
# 3.366716e+10          7059044.0         141972692.0         173258618.0
#
#                Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# MSISDN/Number
# 3.362632e+10          199479238.0         129246502.0       6.745734e+09
# 3.362578e+10          193912238.0         163068369.0       7.171884e+09
# 3.361489e+10          179585986.0         181815060.0       7.622035e+09
# 3.365973e+10          196277206.0         203241873.0       6.609900e+09
# 3.376054e+10          146500839.0         188142430.0       7.316364e+09
# 3.367588e+10          161626462.0         147466697.0       6.863307e+09
# 3.378632e+10          163602702.0         142337088.0       4.740903e+09
# 3.360313e+10          156086546.0         104401875.0       4.108482e+09
# 3.376127e+10          167261139.0         124830202.0       4.165410e+09
# 3.366716e+10          167932406.0         146007082.0       4.623424e+09
#
#                Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)
# MSISDN/Number
# 3.362632e+10         141838597.0      8.025477e+09       142400945.0
# 3.362578e+10         154789688.0      6.201653e+09       152930478.0
# 3.361489e+10         127396833.0      7.495298e+09       143966031.0
# 3.365973e+10         115658741.0      6.182551e+09       134864910.0
# 3.376054e+10         144681056.0      4.590038e+09       126096213.0
# 3.367588e+10         107260559.0      6.665074e+09       133441436.0
# 3.378632e+10         110192303.0      4.172594e+09        79892668.0
# 3.360313e+10          82962892.0      6.222705e+09       103966155.0
# 3.376127e+10         108689309.0      4.997985e+09        79794752.0
# 3.366716e+10         102197663.0      4.837534e+09       103984990.0
#
# Top 10 Customers by Email Usage:
#                session_frequency  session_duration  total_traffic  \
# MSISDN/Number
# 3.361489e+10                17.0         9966898.0   8.846226e+09
# 3.362632e+10                18.0         8791927.0   7.971167e+09
# 3.362578e+10                17.0        18553754.0   8.499621e+09
# 3.378632e+10                12.0         4059652.0   5.622232e+09
# 3.365973e+10                16.0         4035428.0   7.705863e+09
# 3.376054e+10                15.0         9279434.0   8.514774e+09
# 3.366546e+10                 9.0         2566292.0   5.388631e+09
# 3.367588e+10                15.0         4865947.0   7.891111e+09
# 3.369879e+10                11.0         5169128.0   6.540899e+09
# 3.366716e+10                13.0         8744914.0   5.618394e+09
#
#                Social Media DL (Bytes)  Social Media UL (Bytes)  \
# MSISDN/Number
# 3.361489e+10                27749744.0                 544800.0
# 3.362632e+10                42743837.0                 630942.0
# 3.362578e+10                26564121.0                 571379.0
# 3.378632e+10                23568655.0                 406264.0
# 3.365973e+10                34900444.0                 511914.0
# 3.376054e+10                39297646.0                 485543.0
# 3.366546e+10                10331363.0                 223480.0
# 3.367588e+10                18655364.0                 567557.0
# 3.369879e+10                15390784.0                 337377.0
# 3.366716e+10                23753753.0                 494097.0
#
#                Google DL (Bytes)  Google UL (Bytes)  Email DL (Bytes)  \
# MSISDN/Number
# 3.361489e+10          93941708.0         34032079.0        33607211.0
# 3.362632e+10         116106455.0         36085397.0        33404785.0
# 3.362578e+10         107904739.0         34403176.0        31895412.0
# 3.378632e+10          78819810.0         31434674.0        30876908.0
# 3.365973e+10          90958549.0         25557796.0        29907647.0
# 3.376054e+10          88626532.0         34596567.0        26437895.0
# 3.366546e+10          43984050.0         19613376.0        25942871.0
# 3.367588e+10          83002994.0         26857508.0        24284723.0
# 3.369879e+10          59943992.0         19792133.0        24165599.0
# 3.366716e+10          71707826.0         33324870.0        23276752.0
#
#                Email UL (Bytes)  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# MSISDN/Number
# 3.361489e+10          7181423.0         199823443.0         194546775.0
# 3.362632e+10          9013997.0         164048706.0         210434341.0
# 3.362578e+10          8738554.0         237883033.0         215075736.0
# 3.378632e+10          5433215.0         118129859.0          96634053.0
# 3.365973e+10          6092145.0         119658146.0         138332942.0
# 3.376054e+10          7255872.0         194068298.0         202220900.0
# 3.366546e+10          4475014.0         143994297.0          88298235.0
# 3.367588e+10          7229698.0         158665235.0         158745337.0
# 3.369879e+10          4893443.0         166900329.0         135761629.0
# 3.366716e+10          7059044.0         141972692.0         173258618.0
#
#                Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# MSISDN/Number
# 3.361489e+10          179585986.0         181815060.0       7.622035e+09
# 3.362632e+10          199479238.0         129246502.0       6.745734e+09
# 3.362578e+10          193912238.0         163068369.0       7.171884e+09
# 3.378632e+10          163602702.0         142337088.0       4.740903e+09
# 3.365973e+10          196277206.0         203241873.0       6.609900e+09
# 3.376054e+10          146500839.0         188142430.0       7.316364e+09
# 3.366546e+10           83499055.0         114018859.0       4.734492e+09
# 3.367588e+10          161626462.0         147466697.0       6.863307e+09
# 3.369879e+10          103027247.0         165220233.0       5.641128e+09
# 3.366716e+10          167932406.0         146007082.0       4.623424e+09
#
#                Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)
# MSISDN/Number
# 3.361489e+10         127396833.0      7.495298e+09       143966031.0
# 3.362632e+10         141838597.0      8.025477e+09       142400945.0
# 3.362578e+10         154789688.0      6.201653e+09       152930478.0
# 3.378632e+10         110192303.0      4.172594e+09        79892668.0
# 3.365973e+10         115658741.0      6.182551e+09       134864910.0
# 3.376054e+10         144681056.0      4.590038e+09       126096213.0
# 3.366546e+10          46510666.0      2.900205e+09        73247588.0
# 3.367588e+10         107260559.0      6.665074e+09       133441436.0
# 3.369879e+10         112614999.0      4.598153e+09        91723291.0
# 3.366716e+10         102197663.0      4.837534e+09       103984990.0
#
# Top 10 Customers by Youtube Usage:
#                session_frequency  session_duration  total_traffic  \
# MSISDN/Number
# 3.362578e+10                17.0        18553754.0   8.499621e+09
# 3.361489e+10                17.0         9966898.0   8.846226e+09
# 3.376054e+10                15.0         9279434.0   8.514774e+09
# 3.362708e+10                12.0         4703516.0   5.754731e+09
# 3.376041e+10                12.0         5321667.0   7.132371e+09
# 3.369879e+10                11.0         5169128.0   6.540899e+09
# 3.362632e+10                18.0         8791927.0   7.971167e+09
# 3.360313e+10                12.0         6287761.0   4.976195e+09
# 3.367588e+10                15.0         4865947.0   7.891111e+09
# 3.366471e+10                11.0         2927785.0   6.872018e+09
#
#                Social Media DL (Bytes)  Social Media UL (Bytes)  \
# MSISDN/Number
# 3.362578e+10                26564121.0                 571379.0
# 3.361489e+10                27749744.0                 544800.0
# 3.376054e+10                39297646.0                 485543.0
# 3.362708e+10                17438671.0                 370240.0
# 3.376041e+10                20515774.0                 261431.0
# 3.369879e+10                15390784.0                 337377.0
# 3.362632e+10                42743837.0                 630942.0
# 3.360313e+10                22776679.0                 301146.0
# 3.367588e+10                18655364.0                 567557.0
# 3.366471e+10                19035729.0                 354870.0
#
#                Google DL (Bytes)  Google UL (Bytes)  Email DL (Bytes)  \
# MSISDN/Number
# 3.362578e+10         107904739.0         34403176.0        31895412.0
# 3.361489e+10          93941708.0         34032079.0        33607211.0
# 3.376054e+10          88626532.0         34596567.0        26437895.0
# 3.362708e+10          62722401.0         24403520.0        17353955.0
# 3.376041e+10          56331853.0         26406867.0        21791296.0
# 3.369879e+10          59943992.0         19792133.0        24165599.0
# 3.362632e+10         116106455.0         36085397.0        33404785.0
# 3.360313e+10          73942055.0         12986961.0        20343728.0
# 3.367588e+10          83002994.0         26857508.0        24284723.0
# 3.366471e+10          64946017.0         25443355.0        15213560.0
#
#                Email UL (Bytes)  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# MSISDN/Number
# 3.362578e+10          8738554.0         237883033.0         215075736.0
# 3.361489e+10          7181423.0         199823443.0         194546775.0
# 3.376054e+10          7255872.0         194068298.0         202220900.0
# 3.362708e+10          6213264.0         187323322.0         121467452.0
# 3.376041e+10          3785669.0         174245981.0         128923126.0
# 3.369879e+10          4893443.0         166900329.0         135761629.0
# 3.362632e+10          9013997.0         164048706.0         210434341.0
# 3.360313e+10          5855167.0         158976704.0         125113435.0
# 3.367588e+10          7229698.0         158665235.0         158745337.0
# 3.366471e+10          6212447.0         153074482.0         123759531.0
#
#                Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# MSISDN/Number
# 3.362578e+10          193912238.0         163068369.0       7.171884e+09
# 3.361489e+10          179585986.0         181815060.0       7.622035e+09
# 3.376054e+10          146500839.0         188142430.0       7.316364e+09
# 3.362708e+10          144623204.0         122417693.0       4.880017e+09
# 3.376041e+10          167023809.0         151323737.0       6.170943e+09
# 3.369879e+10          103027247.0         165220233.0       5.641128e+09
# 3.362632e+10          199479238.0         129246502.0       6.745734e+09
# 3.360313e+10          156086546.0         104401875.0       4.108482e+09
# 3.367588e+10          161626462.0         147466697.0       6.863307e+09
# 3.366471e+10          134941569.0         116857240.0       6.013562e+09
#
#                Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)
# MSISDN/Number
# 3.362578e+10         154789688.0      6.201653e+09       152930478.0
# 3.361489e+10         127396833.0      7.495298e+09       143966031.0
# 3.376054e+10         144681056.0      4.590038e+09       126096213.0
# 3.362708e+10          92335582.0      5.039747e+09        78044196.0
# 3.376041e+10          97676681.0      3.988504e+09       113141379.0
# 3.369879e+10         112614999.0      4.598153e+09        91723291.0
# 3.362632e+10         141838597.0      8.025477e+09       142400945.0
# 3.360313e+10          82962892.0      6.222705e+09       103966155.0
# 3.367588e+10         107260559.0      6.665074e+09       133441436.0
# 3.366471e+10          90293610.0      3.868637e+09       108323400.0
#
# Top 10 Customers by Netflix Usage:
#                session_frequency  session_duration  total_traffic  \
# MSISDN/Number
# 3.362632e+10                18.0         8791927.0   7.971167e+09
# 3.365973e+10                16.0         4035428.0   7.705863e+09
# 3.362578e+10                17.0        18553754.0   8.499621e+09
# 3.361489e+10                17.0         9966898.0   8.846226e+09
# 3.366716e+10                13.0         8744914.0   5.618394e+09
# 3.376127e+10                10.0         3481629.0   5.051114e+09
# 3.376041e+10                12.0         5321667.0   7.132371e+09
# 3.378632e+10                12.0         4059652.0   5.622232e+09
# 3.367588e+10                15.0         4865947.0   7.891111e+09
# 3.360313e+10                12.0         6287761.0   4.976195e+09
#
#                Social Media DL (Bytes)  Social Media UL (Bytes)  \
# MSISDN/Number
# 3.362632e+10                42743837.0                 630942.0
# 3.365973e+10                34900444.0                 511914.0
# 3.362578e+10                26564121.0                 571379.0
# 3.361489e+10                27749744.0                 544800.0
# 3.366716e+10                23753753.0                 494097.0
# 3.376127e+10                14201427.0                 294653.0
# 3.376041e+10                20515774.0                 261431.0
# 3.378632e+10                23568655.0                 406264.0
# 3.367588e+10                18655364.0                 567557.0
# 3.360313e+10                22776679.0                 301146.0
#
#                Google DL (Bytes)  Google UL (Bytes)  Email DL (Bytes)  \
# MSISDN/Number
# 3.362632e+10         116106455.0         36085397.0        33404785.0
# 3.365973e+10          90958549.0         25557796.0        29907647.0
# 3.362578e+10         107904739.0         34403176.0        31895412.0
# 3.361489e+10          93941708.0         34032079.0        33607211.0
# 3.366716e+10          71707826.0         33324870.0        23276752.0
# 3.376127e+10          72949803.0         24140185.0        15768841.0
# 3.376041e+10          56331853.0         26406867.0        21791296.0
# 3.378632e+10          78819810.0         31434674.0        30876908.0
# 3.367588e+10          83002994.0         26857508.0        24284723.0
# 3.360313e+10          73942055.0         12986961.0        20343728.0
#
#                Email UL (Bytes)  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# MSISDN/Number
# 3.362632e+10          9013997.0         164048706.0         210434341.0
# 3.365973e+10          6092145.0         119658146.0         138332942.0
# 3.362578e+10          8738554.0         237883033.0         215075736.0
# 3.361489e+10          7181423.0         199823443.0         194546775.0
# 3.366716e+10          7059044.0         141972692.0         173258618.0
# 3.376127e+10          4984880.0         119056471.0         153733121.0
# 3.376041e+10          3785669.0         174245981.0         128923126.0
# 3.378632e+10          5433215.0         118129859.0          96634053.0
# 3.367588e+10          7229698.0         158665235.0         158745337.0
# 3.360313e+10          5855167.0         158976704.0         125113435.0
#
#                Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# MSISDN/Number
# 3.362632e+10          199479238.0         129246502.0       6.745734e+09
# 3.365973e+10          196277206.0         203241873.0       6.609900e+09
# 3.362578e+10          193912238.0         163068369.0       7.171884e+09
# 3.361489e+10          179585986.0         181815060.0       7.622035e+09
# 3.366716e+10          167932406.0         146007082.0       4.623424e+09
# 3.376127e+10          167261139.0         124830202.0       4.165410e+09
# 3.376041e+10          167023809.0         151323737.0       6.170943e+09
# 3.378632e+10          163602702.0         142337088.0       4.740903e+09
# 3.367588e+10          161626462.0         147466697.0       6.863307e+09
# 3.360313e+10          156086546.0         104401875.0       4.108482e+09
#
#                Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)
# MSISDN/Number
# 3.362632e+10         141838597.0      8.025477e+09       142400945.0
# 3.365973e+10         115658741.0      6.182551e+09       134864910.0
# 3.362578e+10         154789688.0      6.201653e+09       152930478.0
# 3.361489e+10         127396833.0      7.495298e+09       143966031.0
# 3.366716e+10         102197663.0      4.837534e+09       103984990.0
# 3.376127e+10         108689309.0      4.997985e+09        79794752.0
# 3.376041e+10          97676681.0      3.988504e+09       113141379.0
# 3.378632e+10         110192303.0      4.172594e+09        79892668.0
# 3.367588e+10         107260559.0      6.665074e+09       133441436.0
# 3.360313e+10          82962892.0      6.222705e+09       103966155.0
#
# Top 10 Customers by Gaming Usage:
#                session_frequency  session_duration  total_traffic  \
# MSISDN/Number
# 3.361489e+10                17.0         9966898.0   8.846226e+09
# 3.376054e+10                15.0         9279434.0   8.514774e+09
# 3.362578e+10                17.0        18553754.0   8.499621e+09
# 3.367588e+10                15.0         4865947.0   7.891111e+09
# 3.362632e+10                18.0         8791927.0   7.971167e+09
# 3.365973e+10                16.0         4035428.0   7.705863e+09
# 3.366646e+10                11.0         4536757.0   7.308501e+09
# 3.376041e+10                12.0         5321667.0   7.132371e+09
# 3.366471e+10                11.0         2927785.0   6.872018e+09
# 3.369879e+10                11.0         5169128.0   6.540899e+09
#
#                Social Media DL (Bytes)  Social Media UL (Bytes)  \
# MSISDN/Number
# 3.361489e+10                27749744.0                 544800.0
# 3.376054e+10                39297646.0                 485543.0
# 3.362578e+10                26564121.0                 571379.0
# 3.367588e+10                18655364.0                 567557.0
# 3.362632e+10                42743837.0                 630942.0
# 3.365973e+10                34900444.0                 511914.0
# 3.366646e+10                18234924.0                 395062.0
# 3.376041e+10                20515774.0                 261431.0
# 3.366471e+10                19035729.0                 354870.0
# 3.369879e+10                15390784.0                 337377.0
#
#                Google DL (Bytes)  Google UL (Bytes)  Email DL (Bytes)  \
# MSISDN/Number
# 3.361489e+10          93941708.0         34032079.0        33607211.0
# 3.376054e+10          88626532.0         34596567.0        26437895.0
# 3.362578e+10         107904739.0         34403176.0        31895412.0
# 3.367588e+10          83002994.0         26857508.0        24284723.0
# 3.362632e+10         116106455.0         36085397.0        33404785.0
# 3.365973e+10          90958549.0         25557796.0        29907647.0
# 3.366646e+10          62599213.0         26721524.0        19667181.0
# 3.376041e+10          56331853.0         26406867.0        21791296.0
# 3.366471e+10          64946017.0         25443355.0        15213560.0
# 3.369879e+10          59943992.0         19792133.0        24165599.0
#
#                Email UL (Bytes)  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# MSISDN/Number
# 3.361489e+10          7181423.0         199823443.0         194546775.0
# 3.376054e+10          7255872.0         194068298.0         202220900.0
# 3.362578e+10          8738554.0         237883033.0         215075736.0
# 3.367588e+10          7229698.0         158665235.0         158745337.0
# 3.362632e+10          9013997.0         164048706.0         210434341.0
# 3.365973e+10          6092145.0         119658146.0         138332942.0
# 3.366646e+10          5889958.0         140663858.0          86672154.0
# 3.376041e+10          3785669.0         174245981.0         128923126.0
# 3.366471e+10          6212447.0         153074482.0         123759531.0
# 3.369879e+10          4893443.0         166900329.0         135761629.0
#
#                Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# MSISDN/Number
# 3.361489e+10          179585986.0         181815060.0       7.622035e+09
# 3.376054e+10          146500839.0         188142430.0       7.316364e+09
# 3.362578e+10          193912238.0         163068369.0       7.171884e+09
# 3.367588e+10          161626462.0         147466697.0       6.863307e+09
# 3.362632e+10          199479238.0         129246502.0       6.745734e+09
# 3.365973e+10          196277206.0         203241873.0       6.609900e+09
# 3.366646e+10          115946985.0          98469941.0       6.546328e+09
# 3.376041e+10          167023809.0         151323737.0       6.170943e+09
# 3.366471e+10          134941569.0         116857240.0       6.013562e+09
# 3.369879e+10          103027247.0         165220233.0       5.641128e+09
#
#                Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)
# MSISDN/Number
# 3.361489e+10         127396833.0      7.495298e+09       143966031.0
# 3.376054e+10         144681056.0      4.590038e+09       126096213.0
# 3.362578e+10         154789688.0      6.201653e+09       152930478.0
# 3.367588e+10         107260559.0      6.665074e+09       133441436.0
# 3.362632e+10         141838597.0      8.025477e+09       142400945.0
# 3.365973e+10         115658741.0      6.182551e+09       134864910.0
# 3.366646e+10          99975537.0      4.262205e+09        86936800.0
# 3.376041e+10          97676681.0      3.988504e+09       113141379.0
# 3.366471e+10          90293610.0      3.868637e+09       108323400.0
# 3.369879e+10         112614999.0      4.598153e+09        91723291.0
#
# Top 10 Customers by Other Data Usage:
#                session_frequency  session_duration  total_traffic  \
# MSISDN/Number
# 3.362632e+10                18.0         8791927.0   7.971167e+09
# 3.361489e+10                17.0         9966898.0   8.846226e+09
# 3.367588e+10                15.0         4865947.0   7.891111e+09
# 3.360313e+10                12.0         6287761.0   4.976195e+09
# 3.362578e+10                17.0        18553754.0   8.499621e+09
# 3.365973e+10                16.0         4035428.0   7.705863e+09
# 3.362695e+10                10.0         2415036.0   4.825638e+09
# 3.362708e+10                12.0         4703516.0   5.754731e+09
# 3.376127e+10                10.0         3481629.0   5.051114e+09
# 3.363004e+10                10.0         3635577.0   5.494142e+09
#
#                Social Media DL (Bytes)  Social Media UL (Bytes)  \
# MSISDN/Number
# 3.362632e+10                42743837.0                 630942.0
# 3.361489e+10                27749744.0                 544800.0
# 3.367588e+10                18655364.0                 567557.0
# 3.360313e+10                22776679.0                 301146.0
# 3.362578e+10                26564121.0                 571379.0
# 3.365973e+10                34900444.0                 511914.0
# 3.362695e+10                16589934.0                 332068.0
# 3.362708e+10                17438671.0                 370240.0
# 3.376127e+10                14201427.0                 294653.0
# 3.363004e+10                14458612.0                 352589.0
#
#                Google DL (Bytes)  Google UL (Bytes)  Email DL (Bytes)  \
# MSISDN/Number
# 3.362632e+10         116106455.0         36085397.0        33404785.0
# 3.361489e+10          93941708.0         34032079.0        33607211.0
# 3.367588e+10          83002994.0         26857508.0        24284723.0
# 3.360313e+10          73942055.0         12986961.0        20343728.0
# 3.362578e+10         107904739.0         34403176.0        31895412.0
# 3.365973e+10          90958549.0         25557796.0        29907647.0
# 3.362695e+10          57627757.0         12360190.0        12978989.0
# 3.362708e+10          62722401.0         24403520.0        17353955.0
# 3.376127e+10          72949803.0         24140185.0        15768841.0
# 3.363004e+10          52872797.0         23844746.0        21326155.0
#
#                Email UL (Bytes)  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# MSISDN/Number
# 3.362632e+10          9013997.0         164048706.0         210434341.0
# 3.361489e+10          7181423.0         199823443.0         194546775.0
# 3.367588e+10          7229698.0         158665235.0         158745337.0
# 3.360313e+10          5855167.0         158976704.0         125113435.0
# 3.362578e+10          8738554.0         237883033.0         215075736.0
# 3.365973e+10          6092145.0         119658146.0         138332942.0
# 3.362695e+10          4503799.0          85474648.0         114610592.0
# 3.362708e+10          6213264.0         187323322.0         121467452.0
# 3.376127e+10          4984880.0         119056471.0         153733121.0
# 3.363004e+10          5572088.0         126214062.0         149247942.0
#
#                Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# MSISDN/Number
# 3.362632e+10          199479238.0         129246502.0       6.745734e+09
# 3.361489e+10          179585986.0         181815060.0       7.622035e+09
# 3.367588e+10          161626462.0         147466697.0       6.863307e+09
# 3.360313e+10          156086546.0         104401875.0       4.108482e+09
# 3.362578e+10          193912238.0         163068369.0       7.171884e+09
# 3.365973e+10          196277206.0         203241873.0       6.609900e+09
# 3.362695e+10          117910937.0         144811132.0       4.099560e+09
# 3.362708e+10          144623204.0         122417693.0       4.880017e+09
# 3.376127e+10          167261139.0         124830202.0       4.165410e+09
# 3.363004e+10          144432348.0          88946224.0       4.702908e+09
#
#                Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)
# MSISDN/Number
# 3.362632e+10         141838597.0      8.025477e+09       142400945.0
# 3.361489e+10         127396833.0      7.495298e+09       143966031.0
# 3.367588e+10         107260559.0      6.665074e+09       133441436.0
# 3.360313e+10          82962892.0      6.222705e+09       103966155.0
# 3.362578e+10         154789688.0      6.201653e+09       152930478.0
# 3.365973e+10         115658741.0      6.182551e+09       134864910.0
# 3.362695e+10          82202399.0      5.228772e+09        76675805.0
# 3.362708e+10          92335582.0      5.039747e+09        78044196.0
# 3.376127e+10         108689309.0      4.997985e+09        79794752.0
# 3.363004e+10          91722318.0      4.906609e+09        72243680.0

# %%
for col in aggregated_data:
    print("*"*50)
    print("Top 10 categories for {}".format(col))
    print(aggregated_data[col].value_counts().sort_values(ascending = False).head(10))
    index = aggregated_data[col].value_counts().sort_values(ascending = False).head(10)
    values = aggregated_data[col].value_counts().sort_values(ascending = False).head(10)
    plt.figure(figsize = [10,8])
    plt.pie(values, labels = index,autopct = '%.1f%%')
    plt.xlabel(col)
    plt.ylabel("count of {}".format(col))
    plt.title("Top 10 categories for {} as per the MSISDN/Number ".format(col))
    plt.grid()
    plt.show();
    print('*'*50)
# Out:
# **************************************************
# Top 10 categories for session_frequency
# 1.0     77731
# 2.0     21452
# 3.0      4422
# 4.0      1950
# 5.0       938
# 6.0       208
# 7.0        75
# 8.0        34
# 9.0        17
# 10.0       12
# Name: session_frequency, dtype: int64
# **************************************************
# **************************************************
# Top 10 categories for session_duration
# 86399.0     7873
# 86400.0     2015
# 172798.0    1138
# 172799.0     673
# 259197.0     271
# 259198.0     246
# 345597.0     192
# 345596.0     148
# 172800.0     133
# 431996.0     122
# Name: session_duration, dtype: int64
# **************************************************
# **************************************************
# Top 10 categories for total_traffic
# 477037375.0    2
# 811996647.0    2
# 321294586.0    2
# 375293583.0    2
# 637726002.0    2
# 990132189.0    1
# 599733815.0    1
# 630092434.0    1
# 114976036.0    1
# 732463761.0    1
# Name: total_traffic, dtype: int64
# **************************************************
# **************************************************
# Top 10 categories for Social Media DL (Bytes)
# 2450530.0    3
# 1591078.0    3
# 2586604.0    3
# 2334058.0    3
# 3194199.0    3
# 2159055.0    3
# 2106903.0    3
# 2028429.0    3
# 802637.0     3
# 3263599.0    3
# Name: Social Media DL (Bytes), dtype: int64
# **************************************************
# **************************************************
# Top 10 categories for Social Media UL (Bytes)
# 57952.0    9
# 22250.0    9
# 61754.0    9
# 29179.0    8
# 65459.0    8
# 40418.0    8
# 51638.0    8
# 60828.0    8
# 44123.0    7
# 53496.0    7
# Name: Social Media UL (Bytes), dtype: int64
# **************************************************
# **************************************************
# Top 10 categories for Google DL (Bytes)
# 6839538.0    3
# 8662757.0    3
# 128061.0     2
# 3975587.0    2
# 7326227.0    2
# 7614216.0    2
# 5325995.0    2
# 6653920.0    2
# 7040783.0    2
# 5442830.0    2
# Name: Google DL (Bytes), dtype: int64
# **************************************************
# **************************************************
# Top 10 categories for Google UL (Bytes)
# 2560372.0    3
# 3818169.0    3
# 2305277.0    3
# 2856925.0    3
# 3120933.0    3
# 350338.0     3
# 3557768.0    3
# 716419.0     2
# 2463948.0    2
# 1173790.0    2
# Name: Google UL (Bytes), dtype: int64
# **************************************************
# **************************************************
# Top 10 categories for Email DL (Bytes)
# 3177858.0    3
# 3028657.0    3
# 2243709.0    3
# 3536751.0    3
# 1113690.0    3
# 2863091.0    3
# 136430.0     3
# 1212700.0    3
# 2144315.0    3
# 2978829.0    3
# Name: Email DL (Bytes), dtype: int64
# **************************************************
# **************************************************
# Top 10 categories for Email UL (Bytes)
# 326774.0    4
# 63879.0     4
# 590111.0    4
# 305354.0    4
# 893249.0    4
# 909694.0    4
# 598230.0    4
# 505716.0    4
# 382070.0    3
# 676010.0    3
# Name: Email UL (Bytes), dtype: int64
# **************************************************
# **************************************************
# Top 10 categories for Youtube DL (Bytes)
# 19739158.0    2
# 3364291.0     2
# 16900080.0    2
# 5712949.0     2
# 12073292.0    2
# 10633865.0    2
# 21503895.0    2
# 13920466.0    2
# 13426045.0    2
# 11887559.0    2
# Name: Youtube DL (Bytes), dtype: int64
# **************************************************
# **************************************************
# Top 10 categories for Youtube UL (Bytes)
# 2027396.0     2
# 25167269.0    2
# 830962.0      2
# 4697007.0     2
# 14360637.0    2
# 13520710.0    2
# 212990.0      2
# 12450119.0    2
# 5681048.0     2
# 3650869.0     2
# Name: Youtube UL (Bytes), dtype: int64
# **************************************************
# **************************************************
# Top 10 categories for Netflix DL (Bytes)
# 11475034.0    2
# 2097111.0     2
# 21048072.0    2
# 4474859.0     2
# 15206145.0    2
# 17260640.0    2
# 8029884.0     2
# 660720.0      2
# 21841249.0    2
# 6288023.0     2
# Name: Netflix DL (Bytes), dtype: int64
# **************************************************
# **************************************************
# Top 10 categories for Netflix UL (Bytes)
# 9451822.0     2
# 20814068.0    2
# 4462331.0     2
# 15688382.0    2
# 20864896.0    2
# 16801656.0    2
# 20201855.0    2
# 10121404.0    2
# 721657.0      2
# 13901213.0    2
# Name: Netflix UL (Bytes), dtype: int64
# **************************************************
# **************************************************
# Top 10 categories for Gaming DL (Bytes)
# 6.862361e+08    2
# 1.153043e+08    2
# 1.397145e+08    2
# 8.236561e+08    2
# 7.681073e+08    2
# 6.814473e+08    2
# 6.384263e+08    2
# 6.476069e+08    2
# 3.880748e+08    1
# 1.308981e+09    1
# Name: Gaming DL (Bytes), dtype: int64
# **************************************************
# **************************************************
# Top 10 categories for Gaming UL (Bytes)
# 10079814.0    3
# 13075526.0    2
# 6141584.0     2
# 11863263.0    2
# 14957018.0    2
# 11308299.0    2
# 3965941.0     2
# 16450457.0    2
# 14365103.0    2
# 8143373.0     2
# Name: Gaming UL (Bytes), dtype: int64
# **************************************************
# **************************************************
# Top 10 categories for Other DL (Bytes)
# 7.027837e+08    2
# 3.935565e+08    2
# 1.085264e+08    2
# 7.372510e+08    2
# 1.586779e+08    2
# 6.261997e+08    2
# 1.026521e+09    1
# 4.338359e+08    1
# 5.950361e+08    1
# 5.406972e+08    1
# Name: Other DL (Bytes), dtype: int64
# **************************************************
# **************************************************
# Top 10 categories for Other UL (Bytes)
# 8125986.0     3
# 461452.0      2
# 7607832.0     2
# 10052324.0    2
# 9471492.0     2
# 16037896.0    2
# 8663589.0     2
# 8925465.0     2
# 6213273.0     2
# 13366223.0    2
# Name: Other UL (Bytes), dtype: int64
# **************************************************

# %%
for col in aggregated_data:
    print("*"*50)
    print("Top 10 categories for {}".format(col))
    print(aggregated_data[col].value_counts().sort_values(ascending = False).head(10))
    index = aggregated_data[col].value_counts().sort_values(ascending = False).head(10)
    values = aggregated_data[col].value_counts().sort_values(ascending = False).head(10)
    plt.figure(figsize = [10,8])
    sns.histplot(values,kde=True)
    plt.xlabel(col)
    plt.ylabel("count of {}".format(col))
    plt.title("Top 10 categories for {} based on MSISDN/Number ".format(col))
    plt.grid()
    plt.show();
    print('*'*50)
# Out:
# **************************************************
# Top 10 categories for session_frequency
# 1.0     77731
# 2.0     21452
# 3.0      4422
# 4.0      1950
# 5.0       938
# 6.0       208
# 7.0        75
# 8.0        34
# 9.0        17
# 10.0       12
# Name: session_frequency, dtype: int64
# **************************************************
# **************************************************
# Top 10 categories for session_duration
# 86399.0     7873
# 86400.0     2015
# 172798.0    1138
# 172799.0     673
# 259197.0     271
# 259198.0     246
# 345597.0     192
# 345596.0     148
# 172800.0     133
# 431996.0     122
# Name: session_duration, dtype: int64
# **************************************************
# **************************************************
# Top 10 categories for total_traffic
# 477037375.0    2
# 811996647.0    2
# 321294586.0    2
# 375293583.0    2
# 637726002.0    2
# 990132189.0    1
# 599733815.0    1
# 630092434.0    1
# 114976036.0    1
# 732463761.0    1
# Name: total_traffic, dtype: int64
# **************************************************
# **************************************************
# Top 10 categories for Social Media DL (Bytes)
# 2450530.0    3
# 1591078.0    3
# 2586604.0    3
# 2334058.0    3
# 3194199.0    3
# 2159055.0    3
# 2106903.0    3
# 2028429.0    3
# 802637.0     3
# 3263599.0    3
# Name: Social Media DL (Bytes), dtype: int64
# **************************************************
# **************************************************
# Top 10 categories for Social Media UL (Bytes)
# 57952.0    9
# 22250.0    9
# 61754.0    9
# 29179.0    8
# 65459.0    8
# 40418.0    8
# 51638.0    8
# 60828.0    8
# 44123.0    7
# 53496.0    7
# Name: Social Media UL (Bytes), dtype: int64
# **************************************************
# **************************************************
# Top 10 categories for Google DL (Bytes)
# 6839538.0    3
# 8662757.0    3
# 128061.0     2
# 3975587.0    2
# 7326227.0    2
# 7614216.0    2
# 5325995.0    2
# 6653920.0    2
# 7040783.0    2
# 5442830.0    2
# Name: Google DL (Bytes), dtype: int64
# **************************************************
# **************************************************
# Top 10 categories for Google UL (Bytes)
# 2560372.0    3
# 3818169.0    3
# 2305277.0    3
# 2856925.0    3
# 3120933.0    3
# 350338.0     3
# 3557768.0    3
# 716419.0     2
# 2463948.0    2
# 1173790.0    2
# Name: Google UL (Bytes), dtype: int64
# **************************************************
# **************************************************
# Top 10 categories for Email DL (Bytes)
# 3177858.0    3
# 3028657.0    3
# 2243709.0    3
# 3536751.0    3
# 1113690.0    3
# 2863091.0    3
# 136430.0     3
# 1212700.0    3
# 2144315.0    3
# 2978829.0    3
# Name: Email DL (Bytes), dtype: int64
# **************************************************
# **************************************************
# Top 10 categories for Email UL (Bytes)
# 326774.0    4
# 63879.0     4
# 590111.0    4
# 305354.0    4
# 893249.0    4
# 909694.0    4
# 598230.0    4
# 505716.0    4
# 382070.0    3
# 676010.0    3
# Name: Email UL (Bytes), dtype: int64
# **************************************************
# **************************************************
# Top 10 categories for Youtube DL (Bytes)
# 19739158.0    2
# 3364291.0     2
# 16900080.0    2
# 5712949.0     2
# 12073292.0    2
# 10633865.0    2
# 21503895.0    2
# 13920466.0    2
# 13426045.0    2
# 11887559.0    2
# Name: Youtube DL (Bytes), dtype: int64
# **************************************************
# **************************************************
# Top 10 categories for Youtube UL (Bytes)
# 2027396.0     2
# 25167269.0    2
# 830962.0      2
# 4697007.0     2
# 14360637.0    2
# 13520710.0    2
# 212990.0      2
# 12450119.0    2
# 5681048.0     2
# 3650869.0     2
# Name: Youtube UL (Bytes), dtype: int64
# **************************************************
# **************************************************
# Top 10 categories for Netflix DL (Bytes)
# 11475034.0    2
# 2097111.0     2
# 21048072.0    2
# 4474859.0     2
# 15206145.0    2
# 17260640.0    2
# 8029884.0     2
# 660720.0      2
# 21841249.0    2
# 6288023.0     2
# Name: Netflix DL (Bytes), dtype: int64
# **************************************************
# **************************************************
# Top 10 categories for Netflix UL (Bytes)
# 9451822.0     2
# 20814068.0    2
# 4462331.0     2
# 15688382.0    2
# 20864896.0    2
# 16801656.0    2
# 20201855.0    2
# 10121404.0    2
# 721657.0      2
# 13901213.0    2
# Name: Netflix UL (Bytes), dtype: int64
# **************************************************
# **************************************************
# Top 10 categories for Gaming DL (Bytes)
# 6.862361e+08    2
# 1.153043e+08    2
# 1.397145e+08    2
# 8.236561e+08    2
# 7.681073e+08    2
# 6.814473e+08    2
# 6.384263e+08    2
# 6.476069e+08    2
# 3.880748e+08    1
# 1.308981e+09    1
# Name: Gaming DL (Bytes), dtype: int64
# **************************************************
# **************************************************
# Top 10 categories for Gaming UL (Bytes)
# 10079814.0    3
# 13075526.0    2
# 6141584.0     2
# 11863263.0    2
# 14957018.0    2
# 11308299.0    2
# 3965941.0     2
# 16450457.0    2
# 14365103.0    2
# 8143373.0     2
# Name: Gaming UL (Bytes), dtype: int64
# **************************************************
# **************************************************
# Top 10 categories for Other DL (Bytes)
# 7.027837e+08    2
# 3.935565e+08    2
# 1.085264e+08    2
# 7.372510e+08    2
# 1.586779e+08    2
# 6.261997e+08    2
# 1.026521e+09    1
# 4.338359e+08    1
# 5.950361e+08    1
# 5.406972e+08    1
# Name: Other DL (Bytes), dtype: int64
# **************************************************
# **************************************************
# Top 10 categories for Other UL (Bytes)
# 8125986.0     3
# 461452.0      2
# 7607832.0     2
# 10052324.0    2
# 9471492.0     2
# 16037896.0    2
# 8663589.0     2
# 8925465.0     2
# 6213273.0     2
# 13366223.0    2
# Name: Other UL (Bytes), dtype: int64
# **************************************************

# %%
aggregated_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 106857 entries, 33601001722.0 to 882397108489451.0
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   session_frequency        106857 non-null  float64
#  1   session_duration         106857 non-null  float64
#  2   total_traffic            106857 non-null  float64
#  3   Social Media DL (Bytes)  106857 non-null  float64
#  4   Social Media UL (Bytes)  106857 non-null  float64
#  5   Google DL (Bytes)        106857 non-null  float64
#  6   Google UL (Bytes)        106857 non-null  float64
#  7   Email DL (Bytes)         106857 non-null  float64
#  8   Email UL (Bytes)         106857 non-null  float64
#  9   Youtube DL (Bytes)       106857 non-null  float64
#  10  Youtube UL (Bytes)       106857 non-null  float64
#  11  Netflix DL (Bytes)       106857 non-null  float64
#  12  Netflix UL (Bytes)       106857 non-null  float64
#  13  Gaming DL (Bytes)        106857 non-null  float64
#  14  Gaming UL (Bytes)        106857 non-null  float64
#  15  Other DL (Bytes)         106857 non-null  float64
#  16  Other UL (Bytes)         106857 non-null  float64
# dtypes: float64(17)
# memory usage: 14.7 MB

# %%
engagement_metrics = ['session_frequency', 'session_duration', 'total_traffic', 'Social Media DL (Bytes)', 'Social Media UL (Bytes)',
                     'Google DL (Bytes)', 'Google UL (Bytes)', 'Email DL (Bytes)', 'Email UL (Bytes)', 'Youtube DL (Bytes)', 'Youtube UL (Bytes)',
                     'Netflix DL (Bytes)', 'Netflix UL (Bytes)', 'Gaming DL (Bytes)', 'Gaming UL (Bytes)', 'Other DL (Bytes)', 'Other UL (Bytes)']

aggregated_data = dframe.groupby('MSISDN/Number')[engagement_metrics].sum()
top_10_customers = {}

for metric in engagement_metrics:
    top_10_customers[metric] = aggregated_data.nlargest(10, metric)
    
for metric, top_10 in top_10_customers.items():
    print(f"Top 10 customers for {metric}:")
    print(top_10)
    print()
# Out:
# Top 10 customers for session_frequency:
#                session_frequency  session_duration  total_traffic  \
# MSISDN/Number
# 4.188282e+10         1982.659079      7.255100e+07   5.317447e+11
# 3.362632e+10          324.000000      8.791927e+06   7.971167e+09
# 3.361489e+10          289.000000      9.966898e+06   8.846226e+09
# 3.362578e+10          289.000000      1.855375e+07   8.499621e+09
# 3.365973e+10          256.000000      4.035428e+06   7.705863e+09
# 3.367588e+10          225.000000      4.865947e+06   7.891111e+09
# 3.376054e+10          225.000000      9.279434e+06   8.514774e+09
# 3.366716e+10          169.000000      8.744914e+06   5.618394e+09
# 3.360313e+10          144.000000      6.287761e+06   4.976195e+09
# 3.360452e+10          144.000000      5.207990e+06   5.487855e+09
#
#                Social Media DL (Bytes)  Social Media UL (Bytes)  \
# MSISDN/Number
# 4.188282e+10                       0.0                      0.0
# 3.362632e+10                42743837.0                 630942.0
# 3.361489e+10                27749744.0                 544800.0
# 3.362578e+10                26564121.0                 571379.0
# 3.365973e+10                34900444.0                 511914.0
# 3.367588e+10                18655364.0                 567557.0
# 3.376054e+10                39297646.0                 485543.0
# 3.366716e+10                23753753.0                 494097.0
# 3.360313e+10                22776679.0                 301146.0
# 3.360452e+10                18083725.0                 392798.0
#
#                Google DL (Bytes)  Google UL (Bytes)  Email DL (Bytes)  \
# MSISDN/Number
# 4.188282e+10                 0.0                0.0               0.0
# 3.362632e+10         116106455.0         36085397.0        33404785.0
# 3.361489e+10          93941708.0         34032079.0        33607211.0
# 3.362578e+10         107904739.0         34403176.0        31895412.0
# 3.365973e+10          90958549.0         25557796.0        29907647.0
# 3.367588e+10          83002994.0         26857508.0        24284723.0
# 3.376054e+10          88626532.0         34596567.0        26437895.0
# 3.366716e+10          71707826.0         33324870.0        23276752.0
# 3.360313e+10          73942055.0         12986961.0        20343728.0
# 3.360452e+10          57706148.0         26108889.0        19397083.0
#
#                Email UL (Bytes)  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# MSISDN/Number
# 4.188282e+10                0.0                 0.0                 0.0
# 3.362632e+10          9013997.0         164048706.0         210434341.0
# 3.361489e+10          7181423.0         199823443.0         194546775.0
# 3.362578e+10          8738554.0         237883033.0         215075736.0
# 3.365973e+10          6092145.0         119658146.0         138332942.0
# 3.367588e+10          7229698.0         158665235.0         158745337.0
# 3.376054e+10          7255872.0         194068298.0         202220900.0
# 3.366716e+10          7059044.0         141972692.0         173258618.0
# 3.360313e+10          5855167.0         158976704.0         125113435.0
# 3.360452e+10          4457346.0          83169358.0          96517390.0
#
#                Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# MSISDN/Number
# 4.188282e+10                  0.0                 0.0       0.000000e+00
# 3.362632e+10          199479238.0         129246502.0       6.745734e+09
# 3.361489e+10          179585986.0         181815060.0       7.622035e+09
# 3.362578e+10          193912238.0         163068369.0       7.171884e+09
# 3.365973e+10          196277206.0         203241873.0       6.609900e+09
# 3.367588e+10          161626462.0         147466697.0       6.863307e+09
# 3.376054e+10          146500839.0         188142430.0       7.316364e+09
# 3.366716e+10          167932406.0         146007082.0       4.623424e+09
# 3.360313e+10          156086546.0         104401875.0       4.108482e+09
# 3.360452e+10          151330389.0         114043873.0       4.766393e+09
#
#                Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)
# MSISDN/Number
# 4.188282e+10                 0.0      0.000000e+00               0.0
# 3.362632e+10         141838597.0      8.025477e+09       142400945.0
# 3.361489e+10         127396833.0      7.495298e+09       143966031.0
# 3.362578e+10         154789688.0      6.201653e+09       152930478.0
# 3.365973e+10         115658741.0      6.182551e+09       134864910.0
# 3.367588e+10         107260559.0      6.665074e+09       133441436.0
# 3.376054e+10         144681056.0      4.590038e+09       126096213.0
# 3.366716e+10         102197663.0      4.837534e+09       103984990.0
# 3.360313e+10          82962892.0      6.222705e+09       103966155.0
# 3.360452e+10          80270693.0      4.059958e+09        69984867.0
#
# Top 10 customers for session_duration:
#                session_frequency  session_duration  total_traffic  \
# MSISDN/Number
# 4.188282e+10         1982.659079      7.255100e+07   5.317447e+11
# 3.362578e+10          289.000000      1.855375e+07   8.499621e+09
# 3.361489e+10          289.000000      9.966898e+06   8.846226e+09
# 3.376054e+10          225.000000      9.279434e+06   8.514774e+09
# 3.362632e+10          324.000000      8.791927e+06   7.971167e+09
# 3.366716e+10          169.000000      8.744914e+06   5.618394e+09
# 3.366284e+10           81.000000      6.614270e+06   4.000098e+09
# 3.366469e+10           81.000000      6.288730e+06   5.682007e+09
# 3.360313e+10          144.000000      6.287761e+06   4.976195e+09
# 3.366746e+10           36.000000      5.649882e+06   2.600522e+09
#
#                Social Media DL (Bytes)  Social Media UL (Bytes)  \
# MSISDN/Number
# 4.188282e+10                       0.0                      0.0
# 3.362578e+10                26564121.0                 571379.0
# 3.361489e+10                27749744.0                 544800.0
# 3.376054e+10                39297646.0                 485543.0
# 3.362632e+10                42743837.0                 630942.0
# 3.366716e+10                23753753.0                 494097.0
# 3.366284e+10                17103694.0                 360240.0
# 3.366469e+10                16834010.0                 351031.0
# 3.360313e+10                22776679.0                 301146.0
# 3.366746e+10                 7606997.0                 177076.0
#
#                Google DL (Bytes)  Google UL (Bytes)  Email DL (Bytes)  \
# MSISDN/Number
# 4.188282e+10                 0.0                0.0               0.0
# 3.362578e+10         107904739.0         34403176.0        31895412.0
# 3.361489e+10          93941708.0         34032079.0        33607211.0
# 3.376054e+10          88626532.0         34596567.0        26437895.0
# 3.362632e+10         116106455.0         36085397.0        33404785.0
# 3.366716e+10          71707826.0         33324870.0        23276752.0
# 3.366284e+10          48489232.0         15474271.0        13707750.0
# 3.366469e+10          54588663.0         18994447.0        12978367.0
# 3.360313e+10          73942055.0         12986961.0        20343728.0
# 3.366746e+10          30111394.0          9322276.0        16987953.0
#
#                Email UL (Bytes)  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# MSISDN/Number
# 4.188282e+10                0.0                 0.0                 0.0
# 3.362578e+10          8738554.0         237883033.0         215075736.0
# 3.361489e+10          7181423.0         199823443.0         194546775.0
# 3.376054e+10          7255872.0         194068298.0         202220900.0
# 3.362632e+10          9013997.0         164048706.0         210434341.0
# 3.366716e+10          7059044.0         141972692.0         173258618.0
# 3.366284e+10          4183849.0         120342889.0         142655957.0
# 3.366469e+10          4601251.0         126220891.0          79146878.0
# 3.360313e+10          5855167.0         158976704.0         125113435.0
# 3.366746e+10          3050111.0          69628569.0          76010354.0
#
#                Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# MSISDN/Number
# 4.188282e+10                  0.0                 0.0       0.000000e+00
# 3.362578e+10          193912238.0         163068369.0       7.171884e+09
# 3.361489e+10          179585986.0         181815060.0       7.622035e+09
# 3.376054e+10          146500839.0         188142430.0       7.316364e+09
# 3.362632e+10          199479238.0         129246502.0       6.745734e+09
# 3.366716e+10          167932406.0         146007082.0       4.623424e+09
# 3.366284e+10          110184890.0          74082924.0       3.283845e+09
# 3.366469e+10          129706681.0         131857877.0       4.939498e+09
# 3.360313e+10          156086546.0         104401875.0       4.108482e+09
# 3.366746e+10           94654071.0          79389387.0       2.115310e+09
#
#                Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)
# MSISDN/Number
# 4.188282e+10                 0.0      0.000000e+00               0.0
# 3.362578e+10         154789688.0      6.201653e+09       152930478.0
# 3.361489e+10         127396833.0      7.495298e+09       143966031.0
# 3.376054e+10         144681056.0      4.590038e+09       126096213.0
# 3.362632e+10         141838597.0      8.025477e+09       142400945.0
# 3.366716e+10         102197663.0      4.837534e+09       103984990.0
# 3.366284e+10          67257928.0      3.893377e+09       102409203.0
# 3.366469e+10          69322418.0      4.862951e+09        97906902.0
# 3.360313e+10          82962892.0      6.222705e+09       103966155.0
# 3.366746e+10          42848778.0      2.776996e+09        55424665.0
#
# Top 10 customers for total_traffic:
#                session_frequency  session_duration  total_traffic  \
# MSISDN/Number
# 4.188282e+10         1982.659079      7.255100e+07   5.317447e+11
# 3.361489e+10          289.000000      9.966898e+06   8.846226e+09
# 3.376054e+10          225.000000      9.279434e+06   8.514774e+09
# 3.362578e+10          289.000000      1.855375e+07   8.499621e+09
# 3.362632e+10          324.000000      8.791927e+06   7.971167e+09
# 3.367588e+10          225.000000      4.865947e+06   7.891111e+09
# 3.365973e+10          256.000000      4.035428e+06   7.705863e+09
# 3.366646e+10          121.000000      4.536757e+06   7.308501e+09
# 3.376041e+10          144.000000      5.321667e+06   7.132371e+09
# 3.366471e+10          121.000000      2.927785e+06   6.872018e+09
#
#                Social Media DL (Bytes)  Social Media UL (Bytes)  \
# MSISDN/Number
# 4.188282e+10                       0.0                      0.0
# 3.361489e+10                27749744.0                 544800.0
# 3.376054e+10                39297646.0                 485543.0
# 3.362578e+10                26564121.0                 571379.0
# 3.362632e+10                42743837.0                 630942.0
# 3.367588e+10                18655364.0                 567557.0
# 3.365973e+10                34900444.0                 511914.0
# 3.366646e+10                18234924.0                 395062.0
# 3.376041e+10                20515774.0                 261431.0
# 3.366471e+10                19035729.0                 354870.0
#
#                Google DL (Bytes)  Google UL (Bytes)  Email DL (Bytes)  \
# MSISDN/Number
# 4.188282e+10                 0.0                0.0               0.0
# 3.361489e+10          93941708.0         34032079.0        33607211.0
# 3.376054e+10          88626532.0         34596567.0        26437895.0
# 3.362578e+10         107904739.0         34403176.0        31895412.0
# 3.362632e+10         116106455.0         36085397.0        33404785.0
# 3.367588e+10          83002994.0         26857508.0        24284723.0
# 3.365973e+10          90958549.0         25557796.0        29907647.0
# 3.366646e+10          62599213.0         26721524.0        19667181.0
# 3.376041e+10          56331853.0         26406867.0        21791296.0
# 3.366471e+10          64946017.0         25443355.0        15213560.0
#
#                Email UL (Bytes)  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# MSISDN/Number
# 4.188282e+10                0.0                 0.0                 0.0
# 3.361489e+10          7181423.0         199823443.0         194546775.0
# 3.376054e+10          7255872.0         194068298.0         202220900.0
# 3.362578e+10          8738554.0         237883033.0         215075736.0
# 3.362632e+10          9013997.0         164048706.0         210434341.0
# 3.367588e+10          7229698.0         158665235.0         158745337.0
# 3.365973e+10          6092145.0         119658146.0         138332942.0
# 3.366646e+10          5889958.0         140663858.0          86672154.0
# 3.376041e+10          3785669.0         174245981.0         128923126.0
# 3.366471e+10          6212447.0         153074482.0         123759531.0
#
#                Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# MSISDN/Number
# 4.188282e+10                  0.0                 0.0       0.000000e+00
# 3.361489e+10          179585986.0         181815060.0       7.622035e+09
# 3.376054e+10          146500839.0         188142430.0       7.316364e+09
# 3.362578e+10          193912238.0         163068369.0       7.171884e+09
# 3.362632e+10          199479238.0         129246502.0       6.745734e+09
# 3.367588e+10          161626462.0         147466697.0       6.863307e+09
# 3.365973e+10          196277206.0         203241873.0       6.609900e+09
# 3.366646e+10          115946985.0          98469941.0       6.546328e+09
# 3.376041e+10          167023809.0         151323737.0       6.170943e+09
# 3.366471e+10          134941569.0         116857240.0       6.013562e+09
#
#                Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)
# MSISDN/Number
# 4.188282e+10                 0.0      0.000000e+00               0.0
# 3.361489e+10         127396833.0      7.495298e+09       143966031.0
# 3.376054e+10         144681056.0      4.590038e+09       126096213.0
# 3.362578e+10         154789688.0      6.201653e+09       152930478.0
# 3.362632e+10         141838597.0      8.025477e+09       142400945.0
# 3.367588e+10         107260559.0      6.665074e+09       133441436.0
# 3.365973e+10         115658741.0      6.182551e+09       134864910.0
# 3.366646e+10          99975537.0      4.262205e+09        86936800.0
# 3.376041e+10          97676681.0      3.988504e+09       113141379.0
# 3.366471e+10          90293610.0      3.868637e+09       108323400.0
#
# Top 10 customers for Social Media DL (Bytes):
#                session_frequency  session_duration  total_traffic  \
# MSISDN/Number
# 3.362632e+10               324.0         8791927.0   7.971167e+09
# 3.376054e+10               225.0         9279434.0   8.514774e+09
# 3.365973e+10               256.0         4035428.0   7.705863e+09
# 3.361489e+10               289.0         9966898.0   8.846226e+09
# 3.362578e+10               289.0        18553754.0   8.499621e+09
# 3.366716e+10               169.0         8744914.0   5.618394e+09
# 3.378632e+10               144.0         4059652.0   5.622232e+09
# 3.366907e+10               121.0          610801.0   3.906542e+09
# 3.360313e+10               144.0         6287761.0   4.976195e+09
# 3.365849e+10                81.0         3061779.0   2.690139e+09
#
#                Social Media DL (Bytes)  Social Media UL (Bytes)  \
# MSISDN/Number
# 3.362632e+10                42743837.0                 630942.0
# 3.376054e+10                39297646.0                 485543.0
# 3.365973e+10                34900444.0                 511914.0
# 3.361489e+10                27749744.0                 544800.0
# 3.362578e+10                26564121.0                 571379.0
# 3.366716e+10                23753753.0                 494097.0
# 3.378632e+10                23568655.0                 406264.0
# 3.366907e+10                23477047.0                 323787.0
# 3.360313e+10                22776679.0                 301146.0
# 3.365849e+10                22695673.0                 304393.0
#
#                Google DL (Bytes)  Google UL (Bytes)  Email DL (Bytes)  \
# MSISDN/Number
# 3.362632e+10         116106455.0         36085397.0        33404785.0
# 3.376054e+10          88626532.0         34596567.0        26437895.0
# 3.365973e+10          90958549.0         25557796.0        29907647.0
# 3.361489e+10          93941708.0         34032079.0        33607211.0
# 3.362578e+10         107904739.0         34403176.0        31895412.0
# 3.366716e+10          71707826.0         33324870.0        23276752.0
# 3.378632e+10          78819810.0         31434674.0        30876908.0
# 3.366907e+10          54915216.0         22909468.0        17813584.0
# 3.360313e+10          73942055.0         12986961.0        20343728.0
# 3.365849e+10          55457602.0         20976541.0        15004556.0
#
#                Email UL (Bytes)  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# MSISDN/Number
# 3.362632e+10          9013997.0         164048706.0         210434341.0
# 3.376054e+10          7255872.0         194068298.0         202220900.0
# 3.365973e+10          6092145.0         119658146.0         138332942.0
# 3.361489e+10          7181423.0         199823443.0         194546775.0
# 3.362578e+10          8738554.0         237883033.0         215075736.0
# 3.366716e+10          7059044.0         141972692.0         173258618.0
# 3.378632e+10          5433215.0         118129859.0          96634053.0
# 3.366907e+10          5109829.0         136295265.0         100107539.0
# 3.360313e+10          5855167.0         158976704.0         125113435.0
# 3.365849e+10          4673135.0          64799443.0         118464776.0
#
#                Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# MSISDN/Number
# 3.362632e+10          199479238.0         129246502.0       6.745734e+09
# 3.376054e+10          146500839.0         188142430.0       7.316364e+09
# 3.365973e+10          196277206.0         203241873.0       6.609900e+09
# 3.361489e+10          179585986.0         181815060.0       7.622035e+09
# 3.362578e+10          193912238.0         163068369.0       7.171884e+09
# 3.366716e+10          167932406.0         146007082.0       4.623424e+09
# 3.378632e+10          163602702.0         142337088.0       4.740903e+09
# 3.366907e+10           78923699.0         133085331.0       3.166462e+09
# 3.360313e+10          156086546.0         104401875.0       4.108482e+09
# 3.365849e+10           78217369.0         108576562.0       2.071045e+09
#
#                Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)
# MSISDN/Number
# 3.362632e+10         141838597.0      8.025477e+09       142400945.0
# 3.376054e+10         144681056.0      4.590038e+09       126096213.0
# 3.365973e+10         115658741.0      6.182551e+09       134864910.0
# 3.361489e+10         127396833.0      7.495298e+09       143966031.0
# 3.362578e+10         154789688.0      6.201653e+09       152930478.0
# 3.366716e+10         102197663.0      4.837534e+09       103984990.0
# 3.378632e+10         110192303.0      4.172594e+09        79892668.0
# 3.366907e+10         102690051.0      4.540939e+09        64429870.0
# 3.360313e+10          82962892.0      6.222705e+09       103966155.0
# 3.365849e+10          54024030.0      4.239611e+09        75899582.0
#
# Top 10 customers for Social Media UL (Bytes):
#                session_frequency  session_duration  total_traffic  \
# MSISDN/Number
# 3.362632e+10               324.0         8791927.0   7.971167e+09
# 3.362578e+10               289.0        18553754.0   8.499621e+09
# 3.367588e+10               225.0         4865947.0   7.891111e+09
# 3.361489e+10               289.0         9966898.0   8.846226e+09
# 3.365973e+10               256.0         4035428.0   7.705863e+09
# 3.366716e+10               169.0         8744914.0   5.618394e+09
# 3.376054e+10               225.0         9279434.0   8.514774e+09
# 3.365836e+10               100.0         2131710.0   6.452398e+09
# 3.365936e+10               121.0         2671855.0   4.658437e+09
# 3.378632e+10               144.0         4059652.0   5.622232e+09
#
#                Social Media DL (Bytes)  Social Media UL (Bytes)  \
# MSISDN/Number
# 3.362632e+10                42743837.0                 630942.0
# 3.362578e+10                26564121.0                 571379.0
# 3.367588e+10                18655364.0                 567557.0
# 3.361489e+10                27749744.0                 544800.0
# 3.365973e+10                34900444.0                 511914.0
# 3.366716e+10                23753753.0                 494097.0
# 3.376054e+10                39297646.0                 485543.0
# 3.365836e+10                16865613.0                 420146.0
# 3.365936e+10                20912082.0                 409564.0
# 3.378632e+10                23568655.0                 406264.0
#
#                Google DL (Bytes)  Google UL (Bytes)  Email DL (Bytes)  \
# MSISDN/Number
# 3.362632e+10         116106455.0         36085397.0        33404785.0
# 3.362578e+10         107904739.0         34403176.0        31895412.0
# 3.367588e+10          83002994.0         26857508.0        24284723.0
# 3.361489e+10          93941708.0         34032079.0        33607211.0
# 3.365973e+10          90958549.0         25557796.0        29907647.0
# 3.366716e+10          71707826.0         33324870.0        23276752.0
# 3.376054e+10          88626532.0         34596567.0        26437895.0
# 3.365836e+10          58671984.0         17835154.0        17553922.0
# 3.365936e+10          65070647.0         25970371.0        20462458.0
# 3.378632e+10          78819810.0         31434674.0        30876908.0
#
#                Email UL (Bytes)  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# MSISDN/Number
# 3.362632e+10          9013997.0         164048706.0         210434341.0
# 3.362578e+10          8738554.0         237883033.0         215075736.0
# 3.367588e+10          7229698.0         158665235.0         158745337.0
# 3.361489e+10          7181423.0         199823443.0         194546775.0
# 3.365973e+10          6092145.0         119658146.0         138332942.0
# 3.366716e+10          7059044.0         141972692.0         173258618.0
# 3.376054e+10          7255872.0         194068298.0         202220900.0
# 3.365836e+10          2128126.0         119379568.0         141610278.0
# 3.365936e+10          5154458.0          99590899.0         120901067.0
# 3.378632e+10          5433215.0         118129859.0          96634053.0
#
#                Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# MSISDN/Number
# 3.362632e+10          199479238.0         129246502.0       6.745734e+09
# 3.362578e+10          193912238.0         163068369.0       7.171884e+09
# 3.367588e+10          161626462.0         147466697.0       6.863307e+09
# 3.361489e+10          179585986.0         181815060.0       7.622035e+09
# 3.365973e+10          196277206.0         203241873.0       6.609900e+09
# 3.366716e+10          167932406.0         146007082.0       4.623424e+09
# 3.376054e+10          146500839.0         188142430.0       7.316364e+09
# 3.365836e+10          131358936.0         132783142.0       5.628473e+09
# 3.365936e+10          129809895.0         100806903.0       3.919882e+09
# 3.378632e+10          163602702.0         142337088.0       4.740903e+09
#
#                Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)
# MSISDN/Number
# 3.362632e+10         141838597.0      8.025477e+09       142400945.0
# 3.362578e+10         154789688.0      6.201653e+09       152930478.0
# 3.367588e+10         107260559.0      6.665074e+09       133441436.0
# 3.361489e+10         127396833.0      7.495298e+09       143966031.0
# 3.365973e+10         115658741.0      6.182551e+09       134864910.0
# 3.366716e+10         102197663.0      4.837534e+09       103984990.0
# 3.376054e+10         144681056.0      4.590038e+09       126096213.0
# 3.365836e+10          77446285.0      4.905779e+09       107871346.0
# 3.365936e+10          96688838.0      4.518964e+09        52778228.0
# 3.378632e+10         110192303.0      4.172594e+09        79892668.0
#
# Top 10 customers for Google DL (Bytes):
#                session_frequency  session_duration  total_traffic  \
# MSISDN/Number
# 3.362632e+10               324.0         8791927.0   7.971167e+09
# 3.362578e+10               289.0        18553754.0   8.499621e+09
# 3.361489e+10               289.0         9966898.0   8.846226e+09
# 3.365973e+10               256.0         4035428.0   7.705863e+09
# 3.376054e+10               225.0         9279434.0   8.514774e+09
# 3.367588e+10               225.0         4865947.0   7.891111e+09
# 3.378632e+10               144.0         4059652.0   5.622232e+09
# 3.360313e+10               144.0         6287761.0   4.976195e+09
# 3.376127e+10               100.0         3481629.0   5.051114e+09
# 3.366716e+10               169.0         8744914.0   5.618394e+09
#
#                Social Media DL (Bytes)  Social Media UL (Bytes)  \
# MSISDN/Number
# 3.362632e+10                42743837.0                 630942.0
# 3.362578e+10                26564121.0                 571379.0
# 3.361489e+10                27749744.0                 544800.0
# 3.365973e+10                34900444.0                 511914.0
# 3.376054e+10                39297646.0                 485543.0
# 3.367588e+10                18655364.0                 567557.0
# 3.378632e+10                23568655.0                 406264.0
# 3.360313e+10                22776679.0                 301146.0
# 3.376127e+10                14201427.0                 294653.0
# 3.366716e+10                23753753.0                 494097.0
#
#                Google DL (Bytes)  Google UL (Bytes)  Email DL (Bytes)  \
# MSISDN/Number
# 3.362632e+10         116106455.0         36085397.0        33404785.0
# 3.362578e+10         107904739.0         34403176.0        31895412.0
# 3.361489e+10          93941708.0         34032079.0        33607211.0
# 3.365973e+10          90958549.0         25557796.0        29907647.0
# 3.376054e+10          88626532.0         34596567.0        26437895.0
# 3.367588e+10          83002994.0         26857508.0        24284723.0
# 3.378632e+10          78819810.0         31434674.0        30876908.0
# 3.360313e+10          73942055.0         12986961.0        20343728.0
# 3.376127e+10          72949803.0         24140185.0        15768841.0
# 3.366716e+10          71707826.0         33324870.0        23276752.0
#
#                Email UL (Bytes)  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# MSISDN/Number
# 3.362632e+10          9013997.0         164048706.0         210434341.0
# 3.362578e+10          8738554.0         237883033.0         215075736.0
# 3.361489e+10          7181423.0         199823443.0         194546775.0
# 3.365973e+10          6092145.0         119658146.0         138332942.0
# 3.376054e+10          7255872.0         194068298.0         202220900.0
# 3.367588e+10          7229698.0         158665235.0         158745337.0
# 3.378632e+10          5433215.0         118129859.0          96634053.0
# 3.360313e+10          5855167.0         158976704.0         125113435.0
# 3.376127e+10          4984880.0         119056471.0         153733121.0
# 3.366716e+10          7059044.0         141972692.0         173258618.0
#
#                Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# MSISDN/Number
# 3.362632e+10          199479238.0         129246502.0       6.745734e+09
# 3.362578e+10          193912238.0         163068369.0       7.171884e+09
# 3.361489e+10          179585986.0         181815060.0       7.622035e+09
# 3.365973e+10          196277206.0         203241873.0       6.609900e+09
# 3.376054e+10          146500839.0         188142430.0       7.316364e+09
# 3.367588e+10          161626462.0         147466697.0       6.863307e+09
# 3.378632e+10          163602702.0         142337088.0       4.740903e+09
# 3.360313e+10          156086546.0         104401875.0       4.108482e+09
# 3.376127e+10          167261139.0         124830202.0       4.165410e+09
# 3.366716e+10          167932406.0         146007082.0       4.623424e+09
#
#                Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)
# MSISDN/Number
# 3.362632e+10         141838597.0      8.025477e+09       142400945.0
# 3.362578e+10         154789688.0      6.201653e+09       152930478.0
# 3.361489e+10         127396833.0      7.495298e+09       143966031.0
# 3.365973e+10         115658741.0      6.182551e+09       134864910.0
# 3.376054e+10         144681056.0      4.590038e+09       126096213.0
# 3.367588e+10         107260559.0      6.665074e+09       133441436.0
# 3.378632e+10         110192303.0      4.172594e+09        79892668.0
# 3.360313e+10          82962892.0      6.222705e+09       103966155.0
# 3.376127e+10         108689309.0      4.997985e+09        79794752.0
# 3.366716e+10         102197663.0      4.837534e+09       103984990.0
#
# Top 10 customers for Google UL (Bytes):
#                session_frequency  session_duration  total_traffic  \
# MSISDN/Number
# 3.362632e+10               324.0         8791927.0   7.971167e+09
# 3.376054e+10               225.0         9279434.0   8.514774e+09
# 3.362578e+10               289.0        18553754.0   8.499621e+09
# 3.361489e+10               289.0         9966898.0   8.846226e+09
# 3.366716e+10               169.0         8744914.0   5.618394e+09
# 3.378632e+10               144.0         4059652.0   5.622232e+09
# 3.367588e+10               225.0         4865947.0   7.891111e+09
# 3.366646e+10               121.0         4536757.0   7.308501e+09
# 3.376041e+10               144.0         5321667.0   7.132371e+09
# 3.360452e+10               144.0         5207990.0   5.487855e+09
#
#                Social Media DL (Bytes)  Social Media UL (Bytes)  \
# MSISDN/Number
# 3.362632e+10                42743837.0                 630942.0
# 3.376054e+10                39297646.0                 485543.0
# 3.362578e+10                26564121.0                 571379.0
# 3.361489e+10                27749744.0                 544800.0
# 3.366716e+10                23753753.0                 494097.0
# 3.378632e+10                23568655.0                 406264.0
# 3.367588e+10                18655364.0                 567557.0
# 3.366646e+10                18234924.0                 395062.0
# 3.376041e+10                20515774.0                 261431.0
# 3.360452e+10                18083725.0                 392798.0
#
#                Google DL (Bytes)  Google UL (Bytes)  Email DL (Bytes)  \
# MSISDN/Number
# 3.362632e+10         116106455.0         36085397.0        33404785.0
# 3.376054e+10          88626532.0         34596567.0        26437895.0
# 3.362578e+10         107904739.0         34403176.0        31895412.0
# 3.361489e+10          93941708.0         34032079.0        33607211.0
# 3.366716e+10          71707826.0         33324870.0        23276752.0
# 3.378632e+10          78819810.0         31434674.0        30876908.0
# 3.367588e+10          83002994.0         26857508.0        24284723.0
# 3.366646e+10          62599213.0         26721524.0        19667181.0
# 3.376041e+10          56331853.0         26406867.0        21791296.0
# 3.360452e+10          57706148.0         26108889.0        19397083.0
#
#                Email UL (Bytes)  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# MSISDN/Number
# 3.362632e+10          9013997.0         164048706.0         210434341.0
# 3.376054e+10          7255872.0         194068298.0         202220900.0
# 3.362578e+10          8738554.0         237883033.0         215075736.0
# 3.361489e+10          7181423.0         199823443.0         194546775.0
# 3.366716e+10          7059044.0         141972692.0         173258618.0
# 3.378632e+10          5433215.0         118129859.0          96634053.0
# 3.367588e+10          7229698.0         158665235.0         158745337.0
# 3.366646e+10          5889958.0         140663858.0          86672154.0
# 3.376041e+10          3785669.0         174245981.0         128923126.0
# 3.360452e+10          4457346.0          83169358.0          96517390.0
#
#                Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# MSISDN/Number
# 3.362632e+10          199479238.0         129246502.0       6.745734e+09
# 3.376054e+10          146500839.0         188142430.0       7.316364e+09
# 3.362578e+10          193912238.0         163068369.0       7.171884e+09
# 3.361489e+10          179585986.0         181815060.0       7.622035e+09
# 3.366716e+10          167932406.0         146007082.0       4.623424e+09
# 3.378632e+10          163602702.0         142337088.0       4.740903e+09
# 3.367588e+10          161626462.0         147466697.0       6.863307e+09
# 3.366646e+10          115946985.0          98469941.0       6.546328e+09
# 3.376041e+10          167023809.0         151323737.0       6.170943e+09
# 3.360452e+10          151330389.0         114043873.0       4.766393e+09
#
#                Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)
# MSISDN/Number
# 3.362632e+10         141838597.0      8.025477e+09       142400945.0
# 3.376054e+10         144681056.0      4.590038e+09       126096213.0
# 3.362578e+10         154789688.0      6.201653e+09       152930478.0
# 3.361489e+10         127396833.0      7.495298e+09       143966031.0
# 3.366716e+10         102197663.0      4.837534e+09       103984990.0
# 3.378632e+10         110192303.0      4.172594e+09        79892668.0
# 3.367588e+10         107260559.0      6.665074e+09       133441436.0
# 3.366646e+10          99975537.0      4.262205e+09        86936800.0
# 3.376041e+10          97676681.0      3.988504e+09       113141379.0
# 3.360452e+10          80270693.0      4.059958e+09        69984867.0
#
# Top 10 customers for Email DL (Bytes):
#                session_frequency  session_duration  total_traffic  \
# MSISDN/Number
# 3.361489e+10               289.0         9966898.0   8.846226e+09
# 3.362632e+10               324.0         8791927.0   7.971167e+09
# 3.362578e+10               289.0        18553754.0   8.499621e+09
# 3.378632e+10               144.0         4059652.0   5.622232e+09
# 3.365973e+10               256.0         4035428.0   7.705863e+09
# 3.376054e+10               225.0         9279434.0   8.514774e+09
# 3.366546e+10                81.0         2566292.0   5.388631e+09
# 3.367588e+10               225.0         4865947.0   7.891111e+09
# 3.369879e+10               121.0         5169128.0   6.540899e+09
# 3.366716e+10               169.0         8744914.0   5.618394e+09
#
#                Social Media DL (Bytes)  Social Media UL (Bytes)  \
# MSISDN/Number
# 3.361489e+10                27749744.0                 544800.0
# 3.362632e+10                42743837.0                 630942.0
# 3.362578e+10                26564121.0                 571379.0
# 3.378632e+10                23568655.0                 406264.0
# 3.365973e+10                34900444.0                 511914.0
# 3.376054e+10                39297646.0                 485543.0
# 3.366546e+10                10331363.0                 223480.0
# 3.367588e+10                18655364.0                 567557.0
# 3.369879e+10                15390784.0                 337377.0
# 3.366716e+10                23753753.0                 494097.0
#
#                Google DL (Bytes)  Google UL (Bytes)  Email DL (Bytes)  \
# MSISDN/Number
# 3.361489e+10          93941708.0         34032079.0        33607211.0
# 3.362632e+10         116106455.0         36085397.0        33404785.0
# 3.362578e+10         107904739.0         34403176.0        31895412.0
# 3.378632e+10          78819810.0         31434674.0        30876908.0
# 3.365973e+10          90958549.0         25557796.0        29907647.0
# 3.376054e+10          88626532.0         34596567.0        26437895.0
# 3.366546e+10          43984050.0         19613376.0        25942871.0
# 3.367588e+10          83002994.0         26857508.0        24284723.0
# 3.369879e+10          59943992.0         19792133.0        24165599.0
# 3.366716e+10          71707826.0         33324870.0        23276752.0
#
#                Email UL (Bytes)  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# MSISDN/Number
# 3.361489e+10          7181423.0         199823443.0         194546775.0
# 3.362632e+10          9013997.0         164048706.0         210434341.0
# 3.362578e+10          8738554.0         237883033.0         215075736.0
# 3.378632e+10          5433215.0         118129859.0          96634053.0
# 3.365973e+10          6092145.0         119658146.0         138332942.0
# 3.376054e+10          7255872.0         194068298.0         202220900.0
# 3.366546e+10          4475014.0         143994297.0          88298235.0
# 3.367588e+10          7229698.0         158665235.0         158745337.0
# 3.369879e+10          4893443.0         166900329.0         135761629.0
# 3.366716e+10          7059044.0         141972692.0         173258618.0
#
#                Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# MSISDN/Number
# 3.361489e+10          179585986.0         181815060.0       7.622035e+09
# 3.362632e+10          199479238.0         129246502.0       6.745734e+09
# 3.362578e+10          193912238.0         163068369.0       7.171884e+09
# 3.378632e+10          163602702.0         142337088.0       4.740903e+09
# 3.365973e+10          196277206.0         203241873.0       6.609900e+09
# 3.376054e+10          146500839.0         188142430.0       7.316364e+09
# 3.366546e+10           83499055.0         114018859.0       4.734492e+09
# 3.367588e+10          161626462.0         147466697.0       6.863307e+09
# 3.369879e+10          103027247.0         165220233.0       5.641128e+09
# 3.366716e+10          167932406.0         146007082.0       4.623424e+09
#
#                Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)
# MSISDN/Number
# 3.361489e+10         127396833.0      7.495298e+09       143966031.0
# 3.362632e+10         141838597.0      8.025477e+09       142400945.0
# 3.362578e+10         154789688.0      6.201653e+09       152930478.0
# 3.378632e+10         110192303.0      4.172594e+09        79892668.0
# 3.365973e+10         115658741.0      6.182551e+09       134864910.0
# 3.376054e+10         144681056.0      4.590038e+09       126096213.0
# 3.366546e+10          46510666.0      2.900205e+09        73247588.0
# 3.367588e+10         107260559.0      6.665074e+09       133441436.0
# 3.369879e+10         112614999.0      4.598153e+09        91723291.0
# 3.366716e+10         102197663.0      4.837534e+09       103984990.0
#
# Top 10 customers for Email UL (Bytes):
#                session_frequency  session_duration  total_traffic  \
# MSISDN/Number
# 3.362632e+10               324.0         8791927.0   7.971167e+09
# 3.362578e+10               289.0        18553754.0   8.499621e+09
# 3.376054e+10               225.0         9279434.0   8.514774e+09
# 3.367588e+10               225.0         4865947.0   7.891111e+09
# 3.361489e+10               289.0         9966898.0   8.846226e+09
# 3.366716e+10               169.0         8744914.0   5.618394e+09
# 3.365982e+10               100.0         4889926.0   3.299376e+09
# 3.362708e+10               144.0         4703516.0   5.754731e+09
# 3.366471e+10               121.0         2927785.0   6.872018e+09
# 3.365973e+10               256.0         4035428.0   7.705863e+09
#
#                Social Media DL (Bytes)  Social Media UL (Bytes)  \
# MSISDN/Number
# 3.362632e+10                42743837.0                 630942.0
# 3.362578e+10                26564121.0                 571379.0
# 3.376054e+10                39297646.0                 485543.0
# 3.367588e+10                18655364.0                 567557.0
# 3.361489e+10                27749744.0                 544800.0
# 3.366716e+10                23753753.0                 494097.0
# 3.365982e+10                19253794.0                 336489.0
# 3.362708e+10                17438671.0                 370240.0
# 3.366471e+10                19035729.0                 354870.0
# 3.365973e+10                34900444.0                 511914.0
#
#                Google DL (Bytes)  Google UL (Bytes)  Email DL (Bytes)  \
# MSISDN/Number
# 3.362632e+10         116106455.0         36085397.0        33404785.0
# 3.362578e+10         107904739.0         34403176.0        31895412.0
# 3.376054e+10          88626532.0         34596567.0        26437895.0
# 3.367588e+10          83002994.0         26857508.0        24284723.0
# 3.361489e+10          93941708.0         34032079.0        33607211.0
# 3.366716e+10          71707826.0         33324870.0        23276752.0
# 3.365982e+10          63171540.0         22183939.0        15896128.0
# 3.362708e+10          62722401.0         24403520.0        17353955.0
# 3.366471e+10          64946017.0         25443355.0        15213560.0
# 3.365973e+10          90958549.0         25557796.0        29907647.0
#
#                Email UL (Bytes)  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# MSISDN/Number
# 3.362632e+10          9013997.0         164048706.0         210434341.0
# 3.362578e+10          8738554.0         237883033.0         215075736.0
# 3.376054e+10          7255872.0         194068298.0         202220900.0
# 3.367588e+10          7229698.0         158665235.0         158745337.0
# 3.361489e+10          7181423.0         199823443.0         194546775.0
# 3.366716e+10          7059044.0         141972692.0         173258618.0
# 3.365982e+10          6937942.0         144048814.0          80994262.0
# 3.362708e+10          6213264.0         187323322.0         121467452.0
# 3.366471e+10          6212447.0         153074482.0         123759531.0
# 3.365973e+10          6092145.0         119658146.0         138332942.0
#
#                Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# MSISDN/Number
# 3.362632e+10          199479238.0         129246502.0       6.745734e+09
# 3.362578e+10          193912238.0         163068369.0       7.171884e+09
# 3.376054e+10          146500839.0         188142430.0       7.316364e+09
# 3.367588e+10          161626462.0         147466697.0       6.863307e+09
# 3.361489e+10          179585986.0         181815060.0       7.622035e+09
# 3.366716e+10          167932406.0         146007082.0       4.623424e+09
# 3.365982e+10          107045248.0          98919787.0       2.601082e+09
# 3.362708e+10          144623204.0         122417693.0       4.880017e+09
# 3.366471e+10          134941569.0         116857240.0       6.013562e+09
# 3.365973e+10          196277206.0         203241873.0       6.609900e+09
#
#                Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)
# MSISDN/Number
# 3.362632e+10         141838597.0      8.025477e+09       142400945.0
# 3.362578e+10         154789688.0      6.201653e+09       152930478.0
# 3.376054e+10         144681056.0      4.590038e+09       126096213.0
# 3.367588e+10         107260559.0      6.665074e+09       133441436.0
# 3.361489e+10         127396833.0      7.495298e+09       143966031.0
# 3.366716e+10         102197663.0      4.837534e+09       103984990.0
# 3.365982e+10          89698523.0      3.346528e+09        49807585.0
# 3.362708e+10          92335582.0      5.039747e+09        78044196.0
# 3.366471e+10          90293610.0      3.868637e+09       108323400.0
# 3.365973e+10         115658741.0      6.182551e+09       134864910.0
#
# Top 10 customers for Youtube DL (Bytes):
#                session_frequency  session_duration  total_traffic  \
# MSISDN/Number
# 3.362578e+10               289.0        18553754.0   8.499621e+09
# 3.361489e+10               289.0         9966898.0   8.846226e+09
# 3.376054e+10               225.0         9279434.0   8.514774e+09
# 3.362708e+10               144.0         4703516.0   5.754731e+09
# 3.376041e+10               144.0         5321667.0   7.132371e+09
# 3.369879e+10               121.0         5169128.0   6.540899e+09
# 3.362632e+10               324.0         8791927.0   7.971167e+09
# 3.360313e+10               144.0         6287761.0   4.976195e+09
# 3.367588e+10               225.0         4865947.0   7.891111e+09
# 3.366471e+10               121.0         2927785.0   6.872018e+09
#
#                Social Media DL (Bytes)  Social Media UL (Bytes)  \
# MSISDN/Number
# ...
# 3.366646e+10          99975537.0      4.262205e+09        86936800.0
# 3.376041e+10          97676681.0      3.988504e+09       113141379.0
# 3.366471e+10          90293610.0      3.868637e+09       108323400.0
# 3.369879e+10         112614999.0      4.598153e+09        91723291.0
#
# Top 10 customers for Gaming UL (Bytes):
#                session_frequency  session_duration  total_traffic  \
# MSISDN/Number
# 3.362578e+10               289.0        18553754.0   8.499621e+09
# 3.376054e+10               225.0         9279434.0   8.514774e+09
# 3.362632e+10               324.0         8791927.0   7.971167e+09
# 3.361489e+10               289.0         9966898.0   8.846226e+09
# 3.365973e+10               256.0         4035428.0   7.705863e+09
# 3.369879e+10               121.0         5169128.0   6.540899e+09
# 3.378632e+10               144.0         4059652.0   5.622232e+09
# 3.376127e+10               100.0         3481629.0   5.051114e+09
# 3.367588e+10               225.0         4865947.0   7.891111e+09
# 3.366907e+10               121.0          610801.0   3.906542e+09
#
#                Social Media DL (Bytes)  Social Media UL (Bytes)  \
# MSISDN/Number
# 3.362578e+10                26564121.0                 571379.0
# 3.376054e+10                39297646.0                 485543.0
# 3.362632e+10                42743837.0                 630942.0
# 3.361489e+10                27749744.0                 544800.0
# 3.365973e+10                34900444.0                 511914.0
# 3.369879e+10                15390784.0                 337377.0
# 3.378632e+10                23568655.0                 406264.0
# 3.376127e+10                14201427.0                 294653.0
# 3.367588e+10                18655364.0                 567557.0
# 3.366907e+10                23477047.0                 323787.0
#
#                Google DL (Bytes)  Google UL (Bytes)  Email DL (Bytes)  \
# MSISDN/Number
# 3.362578e+10         107904739.0         34403176.0        31895412.0
# 3.376054e+10          88626532.0         34596567.0        26437895.0
# 3.362632e+10         116106455.0         36085397.0        33404785.0
# 3.361489e+10          93941708.0         34032079.0        33607211.0
# 3.365973e+10          90958549.0         25557796.0        29907647.0
# 3.369879e+10          59943992.0         19792133.0        24165599.0
# 3.378632e+10          78819810.0         31434674.0        30876908.0
# 3.376127e+10          72949803.0         24140185.0        15768841.0
# 3.367588e+10          83002994.0         26857508.0        24284723.0
# 3.366907e+10          54915216.0         22909468.0        17813584.0
#
#                Email UL (Bytes)  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# MSISDN/Number
# 3.362578e+10          8738554.0         237883033.0         215075736.0
# 3.376054e+10          7255872.0         194068298.0         202220900.0
# 3.362632e+10          9013997.0         164048706.0         210434341.0
# 3.361489e+10          7181423.0         199823443.0         194546775.0
# 3.365973e+10          6092145.0         119658146.0         138332942.0
# 3.369879e+10          4893443.0         166900329.0         135761629.0
# 3.378632e+10          5433215.0         118129859.0          96634053.0
# 3.376127e+10          4984880.0         119056471.0         153733121.0
# 3.367588e+10          7229698.0         158665235.0         158745337.0
# 3.366907e+10          5109829.0         136295265.0         100107539.0
#
#                Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# MSISDN/Number
# 3.362578e+10          193912238.0         163068369.0       7.171884e+09
# 3.376054e+10          146500839.0         188142430.0       7.316364e+09
# 3.362632e+10          199479238.0         129246502.0       6.745734e+09
# 3.361489e+10          179585986.0         181815060.0       7.622035e+09
# 3.365973e+10          196277206.0         203241873.0       6.609900e+09
# 3.369879e+10          103027247.0         165220233.0       5.641128e+09
# 3.378632e+10          163602702.0         142337088.0       4.740903e+09
# 3.376127e+10          167261139.0         124830202.0       4.165410e+09
# 3.367588e+10          161626462.0         147466697.0       6.863307e+09
# 3.366907e+10           78923699.0         133085331.0       3.166462e+09
#
#                Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)
# MSISDN/Number
# 3.362578e+10         154789688.0      6.201653e+09       152930478.0
# 3.376054e+10         144681056.0      4.590038e+09       126096213.0
# 3.362632e+10         141838597.0      8.025477e+09       142400945.0
# 3.361489e+10         127396833.0      7.495298e+09       143966031.0
# 3.365973e+10         115658741.0      6.182551e+09       134864910.0
# 3.369879e+10         112614999.0      4.598153e+09        91723291.0
# 3.378632e+10         110192303.0      4.172594e+09        79892668.0
# 3.376127e+10         108689309.0      4.997985e+09        79794752.0
# 3.367588e+10         107260559.0      6.665074e+09       133441436.0
# 3.366907e+10         102690051.0      4.540939e+09        64429870.0
#
# Top 10 customers for Other DL (Bytes):
#                session_frequency  session_duration  total_traffic  \
# MSISDN/Number
# 3.362632e+10               324.0         8791927.0   7.971167e+09
# 3.361489e+10               289.0         9966898.0   8.846226e+09
# 3.367588e+10               225.0         4865947.0   7.891111e+09
# 3.360313e+10               144.0         6287761.0   4.976195e+09
# 3.362578e+10               289.0        18553754.0   8.499621e+09
# 3.365973e+10               256.0         4035428.0   7.705863e+09
# 3.362695e+10               100.0         2415036.0   4.825638e+09
# 3.362708e+10               144.0         4703516.0   5.754731e+09
# 3.376127e+10               100.0         3481629.0   5.051114e+09
# 3.363004e+10               100.0         3635577.0   5.494142e+09
#
#                Social Media DL (Bytes)  Social Media UL (Bytes)  \
# MSISDN/Number
# 3.362632e+10                42743837.0                 630942.0
# 3.361489e+10                27749744.0                 544800.0
# 3.367588e+10                18655364.0                 567557.0
# 3.360313e+10                22776679.0                 301146.0
# 3.362578e+10                26564121.0                 571379.0
# 3.365973e+10                34900444.0                 511914.0
# 3.362695e+10                16589934.0                 332068.0
# 3.362708e+10                17438671.0                 370240.0
# 3.376127e+10                14201427.0                 294653.0
# 3.363004e+10                14458612.0                 352589.0
#
#                Google DL (Bytes)  Google UL (Bytes)  Email DL (Bytes)  \
# MSISDN/Number
# 3.362632e+10         116106455.0         36085397.0        33404785.0
# 3.361489e+10          93941708.0         34032079.0        33607211.0
# 3.367588e+10          83002994.0         26857508.0        24284723.0
# 3.360313e+10          73942055.0         12986961.0        20343728.0
# 3.362578e+10         107904739.0         34403176.0        31895412.0
# 3.365973e+10          90958549.0         25557796.0        29907647.0
# 3.362695e+10          57627757.0         12360190.0        12978989.0
# 3.362708e+10          62722401.0         24403520.0        17353955.0
# 3.376127e+10          72949803.0         24140185.0        15768841.0
# 3.363004e+10          52872797.0         23844746.0        21326155.0
#
#                Email UL (Bytes)  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# MSISDN/Number
# 3.362632e+10          9013997.0         164048706.0         210434341.0
# 3.361489e+10          7181423.0         199823443.0         194546775.0
# 3.367588e+10          7229698.0         158665235.0         158745337.0
# 3.360313e+10          5855167.0         158976704.0         125113435.0
# 3.362578e+10          8738554.0         237883033.0         215075736.0
# 3.365973e+10          6092145.0         119658146.0         138332942.0
# 3.362695e+10          4503799.0          85474648.0         114610592.0
# 3.362708e+10          6213264.0         187323322.0         121467452.0
# 3.376127e+10          4984880.0         119056471.0         153733121.0
# 3.363004e+10          5572088.0         126214062.0         149247942.0
#
#                Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# MSISDN/Number
# 3.362632e+10          199479238.0         129246502.0       6.745734e+09
# 3.361489e+10          179585986.0         181815060.0       7.622035e+09
# 3.367588e+10          161626462.0         147466697.0       6.863307e+09
# 3.360313e+10          156086546.0         104401875.0       4.108482e+09
# 3.362578e+10          193912238.0         163068369.0       7.171884e+09
# 3.365973e+10          196277206.0         203241873.0       6.609900e+09
# 3.362695e+10          117910937.0         144811132.0       4.099560e+09
# 3.362708e+10          144623204.0         122417693.0       4.880017e+09
# 3.376127e+10          167261139.0         124830202.0       4.165410e+09
# 3.363004e+10          144432348.0          88946224.0       4.702908e+09
#
#                Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)
# MSISDN/Number
# 3.362632e+10         141838597.0      8.025477e+09       142400945.0
# 3.361489e+10         127396833.0      7.495298e+09       143966031.0
# 3.367588e+10         107260559.0      6.665074e+09       133441436.0
# 3.360313e+10          82962892.0      6.222705e+09       103966155.0
# 3.362578e+10         154789688.0      6.201653e+09       152930478.0
# 3.365973e+10         115658741.0      6.182551e+09       134864910.0
# 3.362695e+10          82202399.0      5.228772e+09        76675805.0
# 3.362708e+10          92335582.0      5.039747e+09        78044196.0
# 3.376127e+10         108689309.0      4.997985e+09        79794752.0
# 3.363004e+10          91722318.0      4.906609e+09        72243680.0
#
# Top 10 customers for Other UL (Bytes):
#                session_frequency  session_duration  total_traffic  \
# MSISDN/Number
# 3.362578e+10               289.0        18553754.0   8.499621e+09
# 3.361489e+10               289.0         9966898.0   8.846226e+09
# 3.362632e+10               324.0         8791927.0   7.971167e+09
# 3.365973e+10               256.0         4035428.0   7.705863e+09
# 3.367588e+10               225.0         4865947.0   7.891111e+09
# 3.376054e+10               225.0         9279434.0   8.514774e+09
# 3.376041e+10               144.0         5321667.0   7.132371e+09
# 3.366471e+10               121.0         2927785.0   6.872018e+09
# 3.365836e+10               100.0         2131710.0   6.452398e+09
# 3.366716e+10               169.0         8744914.0   5.618394e+09
#
#                Social Media DL (Bytes)  Social Media UL (Bytes)  \
# MSISDN/Number
# 3.362578e+10                26564121.0                 571379.0
# 3.361489e+10                27749744.0                 544800.0
# 3.362632e+10                42743837.0                 630942.0
# 3.365973e+10                34900444.0                 511914.0
# 3.367588e+10                18655364.0                 567557.0
# 3.376054e+10                39297646.0                 485543.0
# 3.376041e+10                20515774.0                 261431.0
# 3.366471e+10                19035729.0                 354870.0
# 3.365836e+10                16865613.0                 420146.0
# 3.366716e+10                23753753.0                 494097.0
#
#                Google DL (Bytes)  Google UL (Bytes)  Email DL (Bytes)  \
# MSISDN/Number
# 3.362578e+10         107904739.0         34403176.0        31895412.0
# 3.361489e+10          93941708.0         34032079.0        33607211.0
# 3.362632e+10         116106455.0         36085397.0        33404785.0
# 3.365973e+10          90958549.0         25557796.0        29907647.0
# 3.367588e+10          83002994.0         26857508.0        24284723.0
# 3.376054e+10          88626532.0         34596567.0        26437895.0
# 3.376041e+10          56331853.0         26406867.0        21791296.0
# 3.366471e+10          64946017.0         25443355.0        15213560.0
# 3.365836e+10          58671984.0         17835154.0        17553922.0
# 3.366716e+10          71707826.0         33324870.0        23276752.0
#
#                Email UL (Bytes)  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# MSISDN/Number
# 3.362578e+10          8738554.0         237883033.0         215075736.0
# 3.361489e+10          7181423.0         199823443.0         194546775.0
# 3.362632e+10          9013997.0         164048706.0         210434341.0
# 3.365973e+10          6092145.0         119658146.0         138332942.0
# 3.367588e+10          7229698.0         158665235.0         158745337.0
# 3.376054e+10          7255872.0         194068298.0         202220900.0
# 3.376041e+10          3785669.0         174245981.0         128923126.0
# 3.366471e+10          6212447.0         153074482.0         123759531.0
# 3.365836e+10          2128126.0         119379568.0         141610278.0
# 3.366716e+10          7059044.0         141972692.0         173258618.0
#
#                Netflix DL (Bytes)  Netflix UL (Bytes)  Gaming DL (Bytes)  \
# MSISDN/Number
# 3.362578e+10          193912238.0         163068369.0       7.171884e+09
# 3.361489e+10          179585986.0         181815060.0       7.622035e+09
# 3.362632e+10          199479238.0         129246502.0       6.745734e+09
# 3.365973e+10          196277206.0         203241873.0       6.609900e+09
# 3.367588e+10          161626462.0         147466697.0       6.863307e+09
# 3.376054e+10          146500839.0         188142430.0       7.316364e+09
# 3.376041e+10          167023809.0         151323737.0       6.170943e+09
# 3.366471e+10          134941569.0         116857240.0       6.013562e+09
# 3.365836e+10          131358936.0         132783142.0       5.628473e+09
# 3.366716e+10          167932406.0         146007082.0       4.623424e+09
#
#                Gaming UL (Bytes)  Other DL (Bytes)  Other UL (Bytes)
# MSISDN/Number
# 3.362578e+10         154789688.0      6.201653e+09       152930478.0
# 3.361489e+10         127396833.0      7.495298e+09       143966031.0
# 3.362632e+10         141838597.0      8.025477e+09       142400945.0
# 3.365973e+10         115658741.0      6.182551e+09       134864910.0
# 3.367588e+10         107260559.0      6.665074e+09       133441436.0
# 3.376054e+10         144681056.0      4.590038e+09       126096213.0
# 3.376041e+10          97676681.0      3.988504e+09       113141379.0
# 3.366471e+10          90293610.0      3.868637e+09       108323400.0
# 3.365836e+10          77446285.0      4.905779e+09       107871346.0
# 3.366716e+10         102197663.0      4.837534e+09       103984990.0

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans

# %%
scaler = MinMaxScaler()
normalized_data = scaler.fit_transform(aggregated_data[engagement_metrics])

kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(normalized_data)

#Assign cluster label to data
customer_clusters = kmeans.labels_

#Add cluster to aggregate dataframe
aggregated_data['Cluster'] = customer_clusters

#Print the number of customers in each cluster
print(aggregated_data['Cluster'].value_counts())
    
x_metric = 'session_frequency'
y_metric = 'session_duration'

#Create a scatter plot of the clusters
plt.figure(figsize=(10, 6))
for cluster in range(3):
    cluster_data = aggregated_data[aggregated_data['Cluster'] == cluster]
    plt.scatter(cluster_data[x_metric], cluster_data[y_metric], label=f'Cluster {cluster}');
plt.xlabel(x_metric)
plt.ylabel(y_metric)
plt.title('Cluster Analysis')
plt.legend()
plt.show()
# Out:
# 0    78327
# 1    24701
# 2     3829
# Name: Cluster, dtype: int64

# %%
sse = {}
kmax = 10

for k in range(1, kmax + 1):
    kmeans = KMeans(n_clusters=k, max_iter=1000, random_state=42).fit(normalized_data)
    sse[k] = kmeans.inertia_
    
plt.plot(list(sse.keys()), list(sse.values()), marker='o')
plt.xlabel('Number of Cluster (k)')
plt.ylabel('Sum of Squared Errors (SSE)')
plt.title('Elbow Method')
plt.show()

# %%
aggregated_data = dframe.groupby('MSISDN/Number').agg({
    'session_frequency': 'mean',
    'session_duration': 'sum',
    'total_traffic': 'sum',
    'Social Media DL (Bytes)': 'sum',
    'Social Media UL (Bytes)': 'sum',
    'Google DL (Bytes)': 'sum',
    'Google UL (Bytes)': 'sum',
    'Email DL (Bytes)': 'sum',
    'Email UL (Bytes)': 'sum',
    'Youtube DL (Bytes)': 'sum',
    'Youtube UL (Bytes)': 'sum',
    'Netflix DL (Bytes)': 'sum',
    'Netflix UL (Bytes)': 'sum',
    'Gaming DL (Bytes)': 'sum',
    'Gaming UL (Bytes)': 'sum',
    'Other DL (Bytes)': 'sum',
    'Other UL (Bytes)': 'sum',
})

scaler = MinMaxScaler()
normalized_data = scaler.fit_transform(aggregated_data)

kmeans = KMeans(n_clusters=3, random_state=42)
kmeans.fit(normalized_data)


cluster_labels = kmeans.labels_

aggregated_data['Cluster'] = cluster_labels

metrics_per_cluster = aggregated_data.groupby('Cluster').agg(['min', 'max', 'mean', 'sum'])

engaged_users_per_app = {}
top_10_users_per_app = {}
applications = ['Social Media', 'Google', 'Email', 'Youtube', 'Netflix', 'Gaming', 'Other']

for app in applications:
    engaged_users_per_app[app] = aggregated_data[f'{app} DL (Bytes)'] + aggregated_data[f'{app} UL (Bytes)']
    top_10_users_per_app[app] = engaged_users_per_app[app].nlargest(10)
    
print("Engaged Users per Application:")
print(engaged_users_per_app)
print(50*"*")
print("\nTop 10 Most Engaged Users per Application:")
print(top_10_users_per_app)
# Out:
# Engaged Users per Application:
# {'Social Media': MSISDN/Number
# 3.360100e+10    2232135.0
# 3.360100e+10    2660565.0
# 3.360100e+10    3195623.0
# 3.360101e+10     280294.0
# 3.360101e+10    2912542.0
#                   ...
# 3.379000e+10     498569.0
# 4.188282e+10          0.0
# 3.197021e+12     715224.0
# 3.370000e+14     521566.0
# 8.823971e+14    1546088.0
# Length: 106857, dtype: float64, 'Google': MSISDN/Number
# 3.360100e+10     4389005.0
# 3.360100e+10     5334863.0
# 3.360100e+10     3443126.0
# 3.360101e+10     9678493.0
# 3.360101e+10    18499616.0
#                    ...
# 3.379000e+10     5429705.0
# 4.188282e+10           0.0
# 3.197021e+12    10438660.0
# 3.370000e+14     9830617.0
# 8.823971e+14     9218647.0
# Length: 106857, dtype: float64, 'Email': MSISDN/Number
# 3.360100e+10    1331362.0
# 3.360100e+10    3307781.0
# 3.360100e+10    3205380.0
# 3.360101e+10    2284670.0
# 3.360101e+10    3305469.0
#                   ...
# 3.379000e+10    2514097.0
# 4.188282e+10          0.0
# 3.197021e+12    1520771.0
# 3.370000e+14    3318582.0
# 8.823971e+14    3330974.0
# Length: 106857, dtype: float64, 'Youtube': MSISDN/Number
# 3.360100e+10    21624548.0
# 3.360100e+10    12432223.0
# 3.360100e+10    21333570.0
# 3.360101e+10     6977321.0
# 3.360101e+10    41533002.0
#                    ...
# 3.379000e+10    19851572.0
# 4.188282e+10           0.0
# 3.197021e+12    11959905.0
# 3.370000e+14    36734940.0
# 8.823971e+14    40940710.0
# Length: 106857, dtype: float64, 'Netflix': MSISDN/Number
# 3.360100e+10    27180981.0
# 3.360100e+10    11221763.0
# 3.360100e+10    19353900.0
# 3.360101e+10     1942092.0
# 3.360101e+10    49201724.0
#                    ...
# 3.379000e+10     8531060.0
# 4.188282e+10           0.0
# 3.197021e+12    26592300.0
# 3.370000e+14    30905042.0
# 8.823971e+14    28846230.0
# Length: 106857, dtype: float64, 'Gaming': MSISDN/Number
# 3.360100e+10    8.124587e+08
# 3.360100e+10    1.197501e+08
# 3.360100e+10    5.388277e+08
# 3.360101e+10    3.911261e+08
# 3.360101e+10    1.314798e+09
#                     ...
# 3.379000e+10    4.370033e+08
# 4.188282e+10    0.000000e+00
# 3.197021e+12    1.780487e+08
# 3.370000e+14    5.101427e+08
# 8.823971e+14    4.307026e+07
# Length: 106857, dtype: float64, 'Other': MSISDN/Number
# 3.360100e+10    386570872.0
# 3.360100e+10    281710071.0
# 3.360100e+10    501693672.0
# 3.360101e+10     35279702.0
# 3.360101e+10    804804484.0
#                    ...
# 3.379000e+10    211115113.0
# 4.188282e+10            0.0
# 3.197021e+12    470526473.0
# 3.370000e+14    149188439.0
# 8.823971e+14    401360457.0
# Length: 106857, dtype: float64}
# **************************************************
#
# Top 10 Most Engaged Users per Application:
# {'Social Media': MSISDN/Number
# 3.362632e+10    43374779.0
# 3.376054e+10    39783189.0
# 3.365973e+10    35412358.0
# 3.361489e+10    28294544.0
# 3.362578e+10    27135500.0
# 3.366716e+10    24247850.0
# 3.378632e+10    23974919.0
# 3.366907e+10    23800834.0
# 3.360313e+10    23077825.0
# 3.365849e+10    23000066.0
# dtype: float64, 'Google': MSISDN/Number
# 3.362632e+10    152191852.0
# 3.362578e+10    142307915.0
# 3.361489e+10    127973787.0
# 3.376054e+10    123223099.0
# 3.365973e+10    116516345.0
# 3.378632e+10    110254484.0
# 3.367588e+10    109860502.0
# 3.366716e+10    105032696.0
# 3.376127e+10     97089988.0
# 3.369876e+10     91935151.0
# dtype: float64, 'Email': MSISDN/Number
# 3.362632e+10    42418782.0
# 3.361489e+10    40788634.0
# 3.362578e+10    40633966.0
# 3.378632e+10    36310123.0
# 3.365973e+10    35999792.0
# 3.376054e+10    33693767.0
# 3.367588e+10    31514421.0
# 3.366546e+10    30417885.0
# 3.366716e+10    30335796.0
# 3.369879e+10    29059042.0
# dtype: float64, 'Youtube': MSISDN/Number
# 3.362578e+10    452958769.0
# 3.376054e+10    396289198.0
# 3.361489e+10    394370218.0
# 3.362632e+10    374483047.0
# 3.367588e+10    317410572.0
# 3.366716e+10    315231310.0
# 3.362708e+10    308790774.0
# 3.376041e+10    303169107.0
# 3.369879e+10    302661958.0
# 3.360313e+10    284090139.0
# dtype: float64, 'Netflix': MSISDN/Number
# 3.365973e+10    399519079.0
# 3.361489e+10    361401046.0
# 3.362578e+10    356980607.0
# 3.376054e+10    334643269.0
# 3.362632e+10    328725740.0
# 3.376041e+10    318347546.0
# 3.366716e+10    313939488.0
# 3.367588e+10    309093159.0
# 3.378632e+10    305939790.0
# 3.376127e+10    292091341.0
# dtype: float64, 'Gaming': MSISDN/Number
# 3.361489e+10    7.749432e+09
# 3.376054e+10    7.461045e+09
# 3.362578e+10    7.326673e+09
# 3.367588e+10    6.970568e+09
# 3.362632e+10    6.887572e+09
# 3.365973e+10    6.725559e+09
# 3.366646e+10    6.646303e+09
# 3.376041e+10    6.268620e+09
# 3.366471e+10    6.103856e+09
# 3.369879e+10    5.753743e+09
# dtype: float64, 'Other': MSISDN/Number
# 3.362632e+10    8.167878e+09
# 3.361489e+10    7.639264e+09
# 3.367588e+10    6.798515e+09
# 3.362578e+10    6.354583e+09
# 3.360313e+10    6.326671e+09
# 3.365973e+10    6.317415e+09
# 3.362695e+10    5.305448e+09
# 3.362708e+10    5.117791e+09
# 3.376127e+10    5.077779e+09
# 3.365836e+10    5.013651e+09
# dtype: float64}

# %%
#Calcuulate the total engaged users per application
total_engaged_users = [engaged_users_per_app[app].sum() for app in applications]

#Plot the bar graph
plt.figure(figsize=(8, 6))
plt.bar(applications, total_engaged_users)
plt.xlabel('Application')
plt.ylabel('Total Engaged Users')
plt.title('Total Engaged Users per Application')

plt.show()

# %%
#Plot the top 3 most used applications
top_3_applications = ['Netflix', 'Youtube', 'Google']

for app in top_3_applications:
    plt.figure()
    top_10_users = top_10_users_per_app[app]
    x = range(len(top_10_users))
    plt.bar(x, top_10_users, label='Engaged Users')
    plt.xlabel('MSISDN/Number')
    plt.ylabel('Engagement')
    plt.title(f'Top 10 Users - {app}')
    plt.xticks(x, top_10_users.index, rotation='vertical')
    plt.legend()
    plt.show()

# %%
#Calculate the total traffic for each application
app_traffic = aggregated_data.sum().loc[['Social Media DL (Bytes)', 'Google DL (Bytes)', 'Email DL (Bytes)']]

plt.figure(figsize=(10,6))
sns.barplot(x=app_traffic.index, y=app_traffic.values)
plt.xlabel('Application')
plt.ylabel('Total Traffic')
plt.title('Top 3 Most Used Applications')
plt.show()

# %%
model = KMeans(n_clusters = 3,
              max_iter = 1000)

# %%
m1 = aggregated_data

# %%
#Lowest SSE value
kmeans.inertia_
# Out:
# 2241.348060113626

# %%
kmeans.n_iter_
# Out:
# 24

# %%
kmeans.labels_[:10]
# Out:
# array([0, 0, 0, 0, 2, 2, 2, 0, 2, 0])

# %%
cluster
# Out:
# 2

# %%
kmeans = KMeans(n_clusters=2)

kmeans.fit(m1)

labels = kmeans.labels_
print(labels)
# Out:
# [0 0 0 ... 0 0 0]

# %%
len(labels)
# Out:
# 106857

# %%
center = np.array(cluster)

# %%
center
# Out:
# array(2)

# %%
m1.reset_index(drop=True, inplace=True)

m1['Class'] = labels

print(m1)
# Out:
#         session_frequency  session_duration  total_traffic  \
# 0                1.000000      1.167200e+05   8.786906e+08
# 1                1.000000      1.812300e+05   1.568596e+08
# 2                1.000000      1.349690e+05   5.959665e+08
# 3                1.000000      4.987800e+04   4.223207e+08
# 4                2.000000      3.710400e+04   1.457411e+09
# ...                   ...               ...            ...
# 106852           1.000000      1.409880e+05   4.803073e+08
# 106853           1.859905      7.255100e+07   5.317447e+11
# 106854           1.000000      8.773850e+05   2.321240e+08
# 106855           1.000000      2.530300e+05   5.962878e+08
# 106856           1.000000      8.698440e+05   1.391536e+08
#
#         Social Media DL (Bytes)  Social Media UL (Bytes)  Google DL (Bytes)  \
# 0                     2206504.0                  25631.0          3337123.0
# 1                     2598548.0                  62017.0          4197697.0
# 2                     3148004.0                  47619.0          3343483.0
# 3                      251469.0                  28825.0          5937765.0
# 4                     2861230.0                  51312.0         13728668.0
# ...                         ...                      ...                ...
# 106852                 442214.0                  56355.0          1472406.0
# 106853                      0.0                      0.0                0.0
# 106854                 668596.0                  46628.0          8572779.0
# 106855                 496337.0                  25229.0          8215537.0
# 106856                1500145.0                  45943.0          5985089.0
#
#         Google UL (Bytes)  Email DL (Bytes)  Email UL (Bytes)  \
# 0               1051882.0          837400.0          493962.0
# 1               1137166.0         2828821.0          478960.0
# 2                 99643.0         2436500.0          768880.0
# 3               3740728.0         2178618.0          106052.0
# 4               4770948.0         2247808.0         1057661.0
# ...                   ...               ...               ...
# 106852          3957299.0         2513433.0             664.0
# 106853                0.0               0.0               0.0
# 106854          1865881.0          842279.0          678492.0
# 106855          1615080.0         2989663.0          328919.0
# 106856          3233558.0         2518425.0          812549.0
#
#         Youtube DL (Bytes)  Youtube UL (Bytes)  Netflix DL (Bytes)  \
# 0               14900201.0           6724347.0          10265105.0
# 1                5324251.0           7107972.0            770569.0
# 2                2137272.0          19196298.0          16525919.0
# 3                4393123.0           2584198.0           1157362.0
# 4               10339971.0          31193031.0          24971647.0
# ...                    ...                 ...                 ...
# 106852           5596862.0          14254710.0           6929961.0
# 106853                 0.0                 0.0                 0.0
# 106854           9839889.0           2120016.0          10340908.0
# 106855          16690728.0          20044212.0           9983678.0
# 106856          18980320.0          21960390.0          21621336.0
#
#         Netflix UL (Bytes)  Gaming DL (Bytes)  Gaming UL (Bytes)  \
# 0               16915876.0       8.110911e+08          1367528.0
# 1               10451194.0       1.050353e+08         14714780.0
# 2                2827981.0       5.290685e+08          9759228.0
# 3                 784730.0       3.880748e+08          3051292.0
# 4               24230077.0       1.308981e+09          5816727.0
# ...                    ...                ...                ...
# 106852           1601099.0       4.276202e+08          9383076.0
# 106853                 0.0       0.000000e+00                0.0
# 106854          16251392.0       1.645636e+08         13485133.0
# 106855          20921364.0       5.012590e+08          8883653.0
# 106856           7224894.0       2.809228e+07         14977978.0
#
#         Other DL (Bytes)  Other UL (Bytes)  Cluster  Class
# 0            377096990.0         9473882.0        0      0
# 1            279557701.0         2152370.0        0      0
# 2            495086501.0         6607171.0        0      0
# 3             25248001.0        10031701.0        0      0
# 4            777643713.0        27160771.0        2      0
# ...                  ...               ...      ...    ...
# 106852       204636073.0         6479040.0        0      0
# 106853               0.0               0.0        0      1
# 106854       467678100.0         2848373.0        0      0
# 106855       144354057.0         4834382.0        0      0
# 106856       389159720.0        12200737.0        0      0
#
# [106857 rows x 19 columns]

# %%
m1['Class'] = labels
m1
# Out:
#         session_frequency  session_duration  total_traffic  \
# 0                1.000000      1.167200e+05   8.786906e+08
# 1                1.000000      1.812300e+05   1.568596e+08
# 2                1.000000      1.349690e+05   5.959665e+08
# 3                1.000000      4.987800e+04   4.223207e+08
# 4                2.000000      3.710400e+04   1.457411e+09
# ...                   ...               ...            ...
# 106852           1.000000      1.409880e+05   4.803073e+08
# 106853           1.859905      7.255100e+07   5.317447e+11
# 106854           1.000000      8.773850e+05   2.321240e+08
# 106855           1.000000      2.530300e+05   5.962878e+08
# 106856           1.000000      8.698440e+05   1.391536e+08
#
#         Social Media DL (Bytes)  Social Media UL (Bytes)  Google DL (Bytes)  \
# 0                     2206504.0                  25631.0          3337123.0
# 1                     2598548.0                  62017.0          4197697.0
# 2                     3148004.0                  47619.0          3343483.0
# 3                      251469.0                  28825.0          5937765.0
# 4                     2861230.0                  51312.0         13728668.0
# ...                         ...                      ...                ...
# 106852                 442214.0                  56355.0          1472406.0
# 106853                      0.0                      0.0                0.0
# 106854                 668596.0                  46628.0          8572779.0
# 106855                 496337.0                  25229.0          8215537.0
# 106856                1500145.0                  45943.0          5985089.0
#
#         Google UL (Bytes)  Email DL (Bytes)  Email UL (Bytes)  \
# 0               1051882.0          837400.0          493962.0
# 1               1137166.0         2828821.0          478960.0
# 2                 99643.0         2436500.0          768880.0
# 3               3740728.0         2178618.0          106052.0
# 4               4770948.0         2247808.0         1057661.0
# ...                   ...               ...               ...
# 106852          3957299.0         2513433.0             664.0
# 106853                0.0               0.0               0.0
# 106854          1865881.0          842279.0          678492.0
# 106855          1615080.0         2989663.0          328919.0
# 106856          3233558.0         2518425.0          812549.0
#
#         Youtube DL (Bytes)  Youtube UL (Bytes)  Netflix DL (Bytes)  \
# 0               14900201.0           6724347.0          10265105.0
# 1                5324251.0           7107972.0            770569.0
# 2                2137272.0          19196298.0          16525919.0
# 3                4393123.0           2584198.0           1157362.0
# 4               10339971.0          31193031.0          24971647.0
# ...                    ...                 ...                 ...
# 106852           5596862.0          14254710.0           6929961.0
# 106853                 0.0                 0.0                 0.0
# 106854           9839889.0           2120016.0          10340908.0
# 106855          16690728.0          20044212.0           9983678.0
# 106856          18980320.0          21960390.0          21621336.0
#
#         Netflix UL (Bytes)  Gaming DL (Bytes)  Gaming UL (Bytes)  \
# 0               16915876.0       8.110911e+08          1367528.0
# 1               10451194.0       1.050353e+08         14714780.0
# 2                2827981.0       5.290685e+08          9759228.0
# 3                 784730.0       3.880748e+08          3051292.0
# 4               24230077.0       1.308981e+09          5816727.0
# ...                    ...                ...                ...
# 106852           1601099.0       4.276202e+08          9383076.0
# 106853                 0.0       0.000000e+00                0.0
# 106854          16251392.0       1.645636e+08         13485133.0
# 106855          20921364.0       5.012590e+08          8883653.0
# 106856           7224894.0       2.809228e+07         14977978.0
#
#         Other DL (Bytes)  Other UL (Bytes)  Cluster  Class
# 0            377096990.0         9473882.0        0      0
# 1            279557701.0         2152370.0        0      0
# 2            495086501.0         6607171.0        0      0
# 3             25248001.0        10031701.0        0      0
# 4            777643713.0        27160771.0        2      0
# ...                  ...               ...      ...    ...
# 106852       204636073.0         6479040.0        0      0
# 106853               0.0               0.0        0      1
# 106854       467678100.0         2848373.0        0      0
# 106855       144354057.0         4834382.0        0      0
# 106856       389159720.0        12200737.0        0      0
#
# [106857 rows x 19 columns]

# %%
center = kmeans.cluster_centers_
center
# Out:
# array([[1.39379164e+00, 1.46167156e+05, 6.90962103e+08, 2.50208080e+06,
#         4.58860128e+04, 8.01649604e+06, 2.86593838e+06, 2.49735227e+06,
#         6.51443543e+05, 1.62146054e+07, 1.53437939e+07, 1.62063937e+07,
#         1.53319386e+07, 5.88215753e+08, 1.15532580e+07, 5.86991600e+08,
#         1.15171640e+07, 5.03546829e-01],
#        [1.85990533e+00, 7.25510046e+07, 5.31744709e+11, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00]])

# %%
model.fit(m1)
# Out:
# KMeans(max_iter=1000, n_clusters=3)

# %%
cluster = model.cluster_centers_
cluster
# Out:
# array([[ 1.14139012e+00,  1.15678794e+05,  5.31723103e+08,
#          2.05257405e+06,  3.75076112e+04,  6.55586095e+06,
#          2.34440268e+06,  2.04630282e+06,  5.33237487e+05,
#          1.32552920e+07,  1.25629812e+07,  1.32489479e+07,
#          1.25494438e+07,  4.47634918e+08,  9.46754605e+06,
#          4.68015906e+08,  9.43408848e+06,  2.64809176e-01,
#         -1.92107072e-18],
#        [ 1.85990533e+00,  7.25510046e+07,  5.31744709e+11,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          1.00000000e+00],
#        [ 2.73936485e+00,  3.08703112e+05,  1.53987825e+09,
#          4.89843813e+06,  9.05519576e+04,  1.58032613e+07,
#          5.64628787e+06,  4.90193379e+06,  1.28160971e+06,
#          3.19909475e+07,  3.01685340e+07,  3.19727792e+07,
#          3.01656466e+07,  1.33766369e+09,  2.26723593e+07,
#          1.22126077e+09,  2.26222099e+07,  1.77627681e+00,
#         -1.35525272e-19]])

# %%
labels = model.labels_
labels
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
len(labels)
# Out:
# 106857

# %%
m1.columns
# Out:
# Index(['session_frequency', 'session_duration', 'total_traffic',
#        'Social Media DL (Bytes)', 'Social Media UL (Bytes)',
#        'Google DL (Bytes)', 'Google UL (Bytes)', 'Email DL (Bytes)',
#        'Email UL (Bytes)', 'Youtube DL (Bytes)', 'Youtube UL (Bytes)',
#        'Netflix DL (Bytes)', 'Netflix UL (Bytes)', 'Gaming DL (Bytes)',
#        'Gaming UL (Bytes)', 'Other DL (Bytes)', 'Other UL (Bytes)', 'Cluster',
#        'Class'],
#       dtype='object')

# %%
from mpl_toolkits.mplot3d import Axes3D

model = KMeans(n_clusters=3, max_iter=1000)
model.fit(m1)
cluster = model.cluster_centers_
center = np.array(cluster)
labels = model.labels_
aggregated_data['Class'] = labels
m1['Class'] = labels

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x = np.array(m1['session_frequency'])
y = np.array(m1['session_duration'])
z = np.array(m1['total_traffic'])

ax.scatter(center[:, 0], center[:, 1], center[:, 2], marker="X", color='b')
ax.scatter(x, y, z, c=y)

plt.title('session_duration vs session_frequency vs total_traffic')
ax.set_xlabel('session_frequency')
ax.set_ylabel('session_duration')
ax.set_zlabel('total_traffic')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x =m1['session_frequency']
y =m1['session_duration']
z =m1['total_traffic']

ax.scatter(x, y, z)
ax.set_xlabel('session_frequency')
ax.set_xlabel('session_duration')
ax.set_xlabel('total_traffic')

plt.show()

# %%
model = KMeans(n_clusters=3, max_iter=1000)
model.fit(m1)
cluster = model.cluster_centers_
center = np.array(cluster)
labels = model.labels_
m1['Class'] = labels

x = np.array(m1['session_frequency'])
y = np.array(m1['session_duration'])
z = np.array(m1['total_traffic'])
colors = labels

fig = plt.figure(figsize=[15,16])
ax = fig.add_subplot(111, projection='3d')
ax.scatter(center[:, 0], center[:, 1], center[:, 2], color='r')
ax.scatter(x, y, z, c=colors, cmap='RdYlBu_r')
ax.set_xlabel('session_frequency')
ax.set_xlabel('session_duration')
ax.set_xlabel('total_traffic')
plt.title('Session Frequency vs Session Duration vs Total Traffic')
plt.show()

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

plt.subplot(1, 3, 1)
sns.boxplot(x='Class', y='session_frequency', data=m1, color='red')
plt.title('Session Frequency vs Class')

plt.subplot(1, 3, 2)
sns.boxplot(x='Class', y='session_duration', data=m1, color='red')
plt.title('Session Duration vs Class')

plt.subplot(1, 3, 3)
sns.boxplot(x='Class', y='total_traffic', data=m1, color='red')
plt.title('Total Traffic vs Class')

plt.tight_layout()
plt.show()
